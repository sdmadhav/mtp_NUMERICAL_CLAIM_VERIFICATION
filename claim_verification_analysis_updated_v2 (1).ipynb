# %% [markdown]
# # Claim Verification Pipeline
#
# **Pipeline steps :**
# 1. Load data
# 2. Match our questions -> closest QuantTemp question (SBERT cosine similarity)
# 3. Extract target entities from matched QT question (GLiNER)
# 4. Fetch article; if inaccessible, walk fallback snippets
# 5. Build per-article FAISS vector DB
# 6. **NEW: Multi-query retrieval** -- snippet splits (by `...`) + individual target entities as queries
# 7. **NEW: Threshold logic** -- >0.7 swap, 0.5-0.7 keep both, <0.5 snippet only
# 8. **NEW: Entity extraction from chunks** (score > 0.5) + set comparison for TRUE/CONFLICTING signal
# 9. **NEW: Checkpoint saving** -- auto-saves after every N records; resume safely
# 10. **NEW: Empirical analysis** -- inspect 10-20 cases >= 0.6 sim: snippet vs chunk
# 11. Export enriched JSON
#
# ---
# **Decision Logic :**
# ```
# For each question:
#   -> Multi-query FAISS (snippet splits + individual entities)
#     |- Best chunk score > 0.7  -> swap snippet with chunk as evidence
#     |- Best chunk score 0.5-0.7 -> keep chunk + keep original snippet
#     '- Best chunk score < 0.5  -> fall back to snippet only
#
#   -> Collect entities from all chunks with score > 0.5
#     -> Compare against target entities
#       |- Entities match + good chunk -> likely TRUE
#       |- Good chunk + missing entities -> CONFLICTING / possibly FALSE
#       '- No good chunk + missing entities -> CONFLICTING
# ```

# %% [markdown]
# ## 0. Install & Imports

# %%
# !pip install -q gdown gliner trafilatura sentence-transformers faiss-cpu requests tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.4/170.4 kB 13.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 80.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 837.9/837.9 kB 63.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 97.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 34.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 32.2 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_1285/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
import ast, json, os, re, time, warnings
from collections import defaultdict
from typing import List, Optional, Dict, Any

import numpy as np
import faiss
import requests
import torch
import trafilatura
from gliner import GLiNER
from sentence_transformers import SentenceTransformer
from tqdm.notebook import tqdm

warnings.filterwarnings('ignore')

# Config
# DATA_PATH        = "/content/Processed_complete_dataset.json"
DATA_PATH          = "/content/temporal_dataset_with_new_evidences.json"
MATCH_THRESHOLD  = 0.15
TOP_K_SNIPPETS   = 3
CHUNK_SIZE       = 3
CHUNK_OVERLAP    = 1
SBERT_MODEL      = "all-MiniLM-L6-v2"
GLINER_MODEL     = "urchade/gliner_small-v2.1"
GLINER_THRESHOLD = 0.30
DEVICE           = "cuda" if torch.cuda.is_available() else "cpu"

# NEW thresholds from meeting
SCORE_HIGH = 0.95  # > this -> swap snippet with chunk
SCORE_MID  = 0.6  # > this -> keep chunk + snippet; < this -> snippet only

# Checkpoint paths
CHECKPOINT_PATH  = "/content/drive/MyDrive/claim_verification_analysis_updated_v2/checkpoint_records.json"
FINAL_OUTPUT_PATH = "/content/drive/MyDrive/claim_verification_analysis_updated_v2/claim_verification_results_v2.json"

print("Config ready. Device:", DEVICE)

# %% [markdown]
# ## 1. Load Data

# %%
# !gdown --id 1jU264txlUGx4n0lWhb4VP41qBbPk-u_N

with open(DATA_PATH) as f:
    raw = json.load(f)

claims, labels, categories, taxonomy = {}, {}, {}, {}
quantemp_evidences, our_evidences, reranked_evidences = {}, {}, {}

for idx, item in enumerate(raw):
    sid = str(idx)
    claims[sid]             = item["claim"]
    labels[sid]             = item["label"]
    categories[sid]         = item["Category"]
    taxonomy[sid]           = item["taxonomy"]
    quantemp_evidences[sid] = item["quantemp_evidences"]
    our_evidences[sid]      = item["our_evidences"]
    reranked_evidences[sid] = item["reranked_our_evidences"]
sample_ids = list(claims.keys())
print(f"Loaded {len(sample_ids)} claims.")
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1jU264txlUGx4n0lWhb4VP41qBbPk-u_N
# From (redirected): https://drive.google.com/uc?id=1jU264txlUGx4n0lWhb4VP41qBbPk-u_N&confirm=t&uuid=e634a918-5306-46fe-879a-3ee175059df8
# To: /content/Processed_complete_dataset.json
# 100% 252M/252M [00:04<00:00, 54.8MB/s]
# Loaded 4130 claims.

# %%
# from itertools import islice
# # Slice the first 2 items
# claims = dict(islice(claims.items(), 5000))

# %% [markdown]
# ## 2. Load Models (SBERT + GLiNER)

# %%
print(f"Loading SBERT ({SBERT_MODEL})...")
encoder = SentenceTransformer(SBERT_MODEL)

print(f"Loading GLiNER ({GLINER_MODEL}) on {DEVICE}...")
gliner = GLiNER.from_pretrained(GLINER_MODEL)
if DEVICE == "cuda":
    gliner = gliner.to(DEVICE)

print("Models ready")
# Out:
# Loading SBERT (all-MiniLM-L6-v2)...
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Loading GLiNER (urchade/gliner_small-v2.1) on cuda...
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/578 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# Models ready

# %% [markdown]
# ## 3. Question Matching (Our -> QuantTemp)

# %%
def encode(texts):
    return encoder.encode(texts, convert_to_numpy=True, normalize_embeddings=True)

def match_questions(our_qs, qt_qs, threshold=MATCH_THRESHOLD):
    if not qt_qs or not our_qs:
        return [{"our_question": q, "matched_qt_question": None, "score": 0.0} for q in our_qs]
    sim_mat = encode(our_qs) @ encode(qt_qs).T
    results = []
    for i, our_q in enumerate(our_qs):
        best_j   = int(np.argmax(sim_mat[i]))
        best_sim = float(sim_mat[i][best_j])
        results.append({
            "our_question":        our_q,
            "matched_qt_question": qt_qs[best_j] if best_sim >= threshold else None,
            "score":               round(best_sim, 4),
        })
    return results

match_results = {}
for sid in sample_ids:
    our_qs = [item["question"] for item in our_evidences[sid]]
    qt_qs  = [item["questions"].strip() for item in quantemp_evidences[sid]]
    match_results[sid] = match_questions(our_qs, qt_qs)

print("Question matching done.")
# Out:
# Question matching done.

# %% [markdown]
# ## 4. Entity Extraction (GLiNER)

# %%
ENTITY_TYPE_RULES = [
    (r"^who\b",                                                          "PERSON"),
    (r"^which (country|nation|state|government)",                        "GPE"),
    (r"^which (organization|agency|office|body|entity|group|party|committee)", "ORG"),
    (r"^which (program|scheme|policy|act|bill|law|legislation|plan)",    "POLICY_PRODUCT"),
    (r"^which (vaccine|drug|treatment|medication|medicine)",             "MEDICAL_PRODUCT"),
    (r"^which (company|brand|firm|corporation|startup)",                 "ORG"),
    (r"^which\b",                                                        "ENTITY_GENERIC"),
    (r"^what (year|date|time|month|day)",                                "DATE"),
    (r"^when\b",                                                         "DATE"),
    (r"^where\b",                                                        "LOCATION"),
    (r"^how (much|many|often|long|far|high|low)",                        "QUANTITY"),
    (r"^what\b",                                                         "ENTITY_GENERIC"),
]

ENTITY_TYPE_TO_GLINER_LABELS = {
    "PERSON":          ["person", "organization", "government agency", "company", "political party"],
    "GPE":             ["country", "government", "nation", "state", "political body", "city"],
    "ORG":             ["organization", "company", "political party", "government agency", "institution"],
    "POLICY_PRODUCT":  ["policy", "law", "act", "program", "legislation", "scheme", "bill"],
    "MEDICAL_PRODUCT": ["vaccine", "drug", "medication", "medical treatment", "medicine"],
    "DATE":            ["date", "year", "time period", "month"],
    "LOCATION":        ["location", "place", "country", "region", "city"],
    "QUANTITY":        ["percentage", "number", "quantity", "amount", "statistic"],
    "ENTITY_GENERIC":  ["organization", "person", "country", "product", "event", "entity"],
    "UNKNOWN":         ["person", "organization", "country", "location", "event", "product"],
}

_WIDE_LABELS = [
    "person", "organization", "country", "government", "location",
    "date", "number", "percentage", "vaccine", "drug", "law", "policy",
    "product", "event", "political party", "agency",
]

_STOPWORDS = {
    "the","a","an","is","are","was","were","has","have","had","did","do","does",
    "been","be","will","would","could","should","there","it","this","that","of",
    "in","to","for","on","at","by","with","about","or","and","if","than","any",
    "some","all","its","from","more","once","they","get","us","only","certain",
}

def infer_entity_type(question: str) -> str:
    q = question.strip().lower()
    for pattern, etype in ENTITY_TYPE_RULES:
        if re.search(pattern, q):
            return etype
    return "UNKNOWN"

def _gliner_predict(text, labels, threshold):
    try:
        return gliner.predict_entities(text, labels, threshold=threshold)
    except Exception:
        return []

def _dedupe_spans(spans, priority_map, n_labels):
    seen, entities = set(), []
    for span in spans:
        text = span["text"].strip()
        norm = text.lower()
        if norm in seen or len(text) <= 1 or norm in _STOPWORDS:
            continue
        seen.add(norm)
        entities.append({
            "text":     text,
            "label":    span["label"],
            "score":    round(float(span["score"]), 3),
            "priority": priority_map.get(span["label"], n_labels),
        })
    entities.sort(key=lambda e: (e["priority"], -e["score"]))
    return entities

def _noun_phrase_fallback(qt_question: str) -> str:
    q = re.sub(r"^(did|is|are|was|were|has|have|does|do|will|would|could|should)\s+", "", qt_question.strip().rstrip("?"), flags=re.I)
    q = re.sub(r"^(the|a|an)\s+", "", q, flags=re.I)
    phrase = [tok.strip(",.?!;:\"'()") for tok in q.split()
              if tok.strip(",.?!;:\"'()").lower() not in _STOPWORDS and len(tok) > 1][:6]
    return " ".join(phrase) if phrase else qt_question[:60]

def extract_target_entity(our_question: str, qt_question: str):
    if not qt_question or not qt_question.strip():
        return {"entity_type": "UNKNOWN", "best_entity": "", "entities": [], "status": "NO_QT"}
    etype   = infer_entity_type(our_question)
    labels  = ENTITY_TYPE_TO_GLINER_LABELS.get(etype, ENTITY_TYPE_TO_GLINER_LABELS["UNKNOWN"])
    pri_map = {lbl: i for i, lbl in enumerate(labels)}
    spans   = _gliner_predict(qt_question, labels, GLINER_THRESHOLD)
    ents    = _dedupe_spans(spans, pri_map, len(labels))
    if ents:
        status = "OK" if ents[0]["priority"] == 0 else "FALLBACK_LABEL"
        best   = ents[0]["text"]
    else:
        best   = _noun_phrase_fallback(qt_question)
        ents   = [{"text": best, "label": "noun_phrase", "score": 0.0, "priority": 999}]
        status = "FALLBACK_NP"
    return {"entity_type": etype, "best_entity": best, "entities": ents, "status": status}

def scan_all_entities(text: str) -> list:
    if not text or not text.strip():
        return []
    spans = _gliner_predict(text, _WIDE_LABELS, threshold=0.25)
    seen, results = set(), []
    for span in spans:
        norm = span["text"].strip().lower()
        if norm and norm not in seen and norm not in _STOPWORDS and len(norm) > 1:
            seen.add(norm)
            results.append((span["text"].strip(), span["label"]))
    return results

def compute_missing_entities(qt_entities, our_entities):
    our_norms = {t.lower().strip(",.?\"'") for t, _ in our_entities}
    return [
        (qt_text, qt_label)
        for qt_text, qt_label in qt_entities
        if not any(
            qt_text.lower().strip(",.?\"'") == o or
            qt_text.lower() in o or o in qt_text.lower()
            for o in our_norms if len(o) > 2
        )
    ]

def any_entity_in_text(entity_texts, text):
    text_l = text.lower()
    for ent in entity_texts:
        if not ent: continue
        if ent.lower() in text_l:
            return True, ent
        parts = [p for p in ent.lower().split() if p not in _STOPWORDS]
        if len(parts) >= 2 and sum(1 for p in parts if p in text_l) >= max(2, round(len(parts)*0.6)):
            return True, ent
    return False, None

print("Entity extraction helpers defined.")
# Out:
# Entity extraction helpers defined.

# %% [markdown]
# ## 5. Article Fetching with Fallback

# %%
import logging
import concurrent.futures

logging.getLogger("trafilatura").setLevel(logging.ERROR)

def fetch_article(url: str, timeout: int = 5) -> Optional[str]:
    if url.lower().endswith(".pdf") or "pdf" in url.lower():
        return None
    try:
        resp = requests.get(url, timeout=timeout, headers={"User-Agent": "Mozilla/5.0"})
        if resp.status_code != 200:
            return None
        ct = resp.headers.get("Content-Type", "")
        if "pdf" in ct.lower():
            return None
        return trafilatura.extract(resp.text) or None
    except Exception:
        return None

def fetch_best_article(question: str, top_link: str, fallback_results: list):
    text = fetch_article(top_link)
    if text:
        return text, top_link, "top"
    for i, candidate in enumerate(fallback_results):
        url = candidate.get("link", "")
        if not url or url == top_link:
            continue
        if url.lower().endswith(".pdf") or "pdf" in url.lower():
            continue
        text = fetch_article(url)
        if text:
            return text, url, f"fallback_rank_{i+1}"
        if i >= 2:
            break
    return None, None, "failed"

print("Article fetching helpers defined.")
# Out:
# Article fetching helpers defined.

# %% [markdown]
# ## 6. FAISS Vector DB Helpers

# %%
def chunk_text(text: str, chunk_size: int = CHUNK_SIZE, overlap: int = CHUNK_OVERLAP) -> list:
    sentences = [s.strip() for s in text.replace("\n", " ").split(". ") if len(s.strip()) > 20]
    step   = chunk_size - overlap
    chunks = []
    for start in range(0, len(sentences), step):
        window = sentences[start: start + chunk_size]
        if window:
            chunks.append(". ".join(window) + ".")
    return chunks

def build_faiss_index(chunks: list):
    if not chunks:
        return None, []
    embs  = encoder.encode(chunks, normalize_embeddings=True, show_progress_bar=False).astype(np.float32)
    index = faiss.IndexFlatIP(embs.shape[1])
    index.add(embs)
    return index, chunks

def query_index(index, chunks: list, query: str, top_k: int = 3) -> list:
    if index is None or not chunks:
        return []
    q_vec = encoder.encode([query], normalize_embeddings=True, show_progress_bar=False).astype(np.float32)
    scores, idxs = index.search(q_vec, min(top_k, len(chunks)))
    return [{"rank": r+1, "score": round(float(scores[0][r]), 4), "text": chunks[idxs[0][r]]}
            for r in range(len(idxs[0]))]

print("FAISS helpers defined.")
# Out:
# FAISS helpers defined.

# %% [markdown]
# ## 7. NEW -- Multi-Query Retrieval Helpers
#
# **From meeting:**
# - Using only the question as query gives small semantic scores -> poor retrieval.
# - Instead, query FAISS in multiple ways:
#   1. **Snippet splits**: Google snippets use `...` (triple dots). Split by `...` and use each part as a query.
#   2. **Individual target entities**: e.g., "Congressional", "Obamacare", "US" each become separate queries.
# - Collect chunks from all queries and merge them.

# %%
def split_snippet_queries(snippet: str) -> list:
    """
    Split a Google-style snippet by triple dots (...) to get focused sub-queries.
    Google provides the text where the query matches in the page, separated by ...
    Each split becomes a separate FAISS query for better retrieval.
    """
    if not snippet:
        return []
    parts = [p.strip() for p in snippet.split("...")]
    return [p for p in parts if len(p) > 10]   # ignore very short fragments


def get_entity_queries(target_entity_info: dict) -> list:
    """
    From target entity extraction result, return each entity text as a separate query.
    e.g., entities = [{'text': 'Congressional'}, {'text': 'Obamacare'}, {'text': 'US'}]
    -> ['Congressional', 'Obamacare', 'US']
    Individual entity queries improve retrieval for short named entities.
    """
    return [e["text"] for e in target_entity_info.get("entities", []) if e.get("text")]


def multi_query_retrieve(index, chunks: list, queries: list, top_k: int = 3) -> list:
    """
    Run multiple queries against the same FAISS index and combine results.
    Deduplicates by chunk text; keeps the best score per chunk.
    Returns list sorted by descending score.
    """
    if index is None or not chunks or not queries:
        return []

    best = {}   # chunk_text -> best score
    for q in queries:
        if not q or not q.strip():
            continue
        results = query_index(index, chunks, q, top_k=top_k)
        for r in results:
            txt = r["text"]
            if txt not in best or r["score"] > best[txt]:
                best[txt] = r["score"]

    return sorted(
        [{"text": txt, "score": score} for txt, score in best.items()],
        key=lambda x: -x["score"]
    )


def apply_threshold_logic(retrieved_chunks: list, original_snippet: str) -> dict:
    """
    Apply similarity threshold logic from meeting:
      > 0.7  -> swap: use chunk as primary evidence (snippet replaced)
      0.5-0.7 -> keep both chunk and original snippet
      < 0.5  -> fall back to original snippet only (chunk ignored)

    Snippet is ALWAYS kept as baseline/fallback - never removed entirely.
    The snippet should always be there as a safety net.

    Returns dict with:
      best_chunk, best_score, primary_evidence, evidence_source,
      all_chunks_above_mid (for entity extraction)
    """
    if not retrieved_chunks:
        return {
            "best_chunk":          "",
            "best_score":          0.0,
            "primary_evidence":    original_snippet,
            "evidence_source":     "snippet_only",
            "all_chunks_above_mid": [],
        }

    best  = retrieved_chunks[0]   # sorted descending
    score = best["score"]
    chunk = best["text"]
    above_mid = [c for c in retrieved_chunks if c["score"] > SCORE_MID]

    if score > SCORE_HIGH:
        # Very good match -> swap snippet with chunk as evidence
        return {
            "best_chunk":          chunk,
            "best_score":          score,
            "primary_evidence":    chunk,
            "evidence_source":     "chunk_only",
            "all_chunks_above_mid": above_mid,
        }
    elif score > SCORE_MID:
        # Good match -> keep both; original snippet as fallback
        combined = chunk + "\n\n[Original snippet fallback]:\n" + original_snippet
        return {
            "best_chunk":          chunk,
            "best_score":          score,
            "primary_evidence":    combined,
            "evidence_source":     "chunk_and_snippet",
            "all_chunks_above_mid": above_mid,
        }
    else:
        # Poor match -> ignore chunk, use original snippet only
        return {
            "best_chunk":          "",
            "best_score":          score,
            "primary_evidence":    original_snippet,
            "evidence_source":     "snippet_only",
            "all_chunks_above_mid": [],
        }


def extract_entities_from_chunks(chunks_above_mid: list, target_type: str) -> list:
    """
    From all retrieved chunks above mid threshold, extract entities of the target type.
    Returns deduplicated list of entity dicts (text, label, score).
    """
    labels = ENTITY_TYPE_TO_GLINER_LABELS.get(target_type, ENTITY_TYPE_TO_GLINER_LABELS["UNKNOWN"])
    all_entities = []
    seen = set()
    for chunk in chunks_above_mid:
        spans = _gliner_predict(chunk["text"], labels, GLINER_THRESHOLD)
        for span in spans:
            norm = span["text"].strip().lower()
            if norm and norm not in seen and norm not in _STOPWORDS and len(norm) > 1:
                seen.add(norm)
                all_entities.append({
                    "text":  span["text"].strip(),
                    "label": span["label"],
                    "score": round(float(span["score"]), 3),
                })
    return all_entities


def compare_entity_sets(target_entities: list, chunk_entities: list) -> dict:
    """
    Compare target entities (from QT question) with entities found in retrieved chunks.
    Uses subset / superset / intersection / union comparisons.

    Logic:
      - Chunk entities match target -> more likely TRUE
      - Good chunk score + missing target entities -> CONFLICTING / possibly FALSE
      - No good chunk + missing entities -> CONFLICTING

    Note: High similarity does NOT mean the chunk supports the claim.
    A contradicting chunk with high similarity is VALUABLE evidence (can confirm FALSE).
    Example: Yellowstone question -> chunk says 'NOT Yellowstone national park' -> confirms FALSE.

    Returns:
      verdict: TRUE_SIGNAL | CONFLICTING | INSUFFICIENT
    """
    target_norms = {e.lower().strip() for e in target_entities if e}
    chunk_norms  = {e["text"].lower().strip() for e in chunk_entities if e.get("text")}

    if not target_norms:
        return {"verdict": "INSUFFICIENT", "reason": "no_target_entities",
                "match_ratio": 0.0, "intersection": [], "missing": [], "extra": []}

    intersection = target_norms & chunk_norms
    missing      = target_norms - chunk_norms
    extra        = chunk_norms  - target_norms
    match_ratio  = len(intersection) / len(target_norms)

    if match_ratio >= 0.8:
        verdict, reason = "TRUE_SIGNAL",   "entities_match"
    elif intersection and missing:
        verdict, reason = "CONFLICTING",   "partial_match_entities_missing"
    elif not intersection:
        verdict, reason = "CONFLICTING",   "no_matching_entities"
    else:
        verdict, reason = "INSUFFICIENT",  "low_match_ratio"

    return {
        "verdict":     verdict,
        "reason":      reason,
        "match_ratio": round(match_ratio, 3),
        "intersection": list(intersection),
        "missing":      list(missing),
        "extra":        list(extra),
    }


print("Multi-query retrieval helpers defined.")
# Out:
# Multi-query retrieval helpers defined.

# %% [markdown]
# ## 8. Checkpoint Save/Load Helpers
#
# **Why:** Colab sessions expire. Saving progress every N records means you never re-process
# what's already done. Just re-run the pipeline cell and it will pick up from where it left off.

# %%
def save_checkpoint(records: list, path: str = CHECKPOINT_PATH):
    with open(path, "w") as f:
        json.dump(records, f, indent=2)
    print(f"  [Checkpoint] Saved {len(records)} records -> {path}")

def load_checkpoint(path: str = CHECKPOINT_PATH) -> list:
    if not os.path.exists(path):
        print(f"  [Checkpoint] No checkpoint at {path}. Starting fresh.")
        return []
    with open(path) as f:
        records = json.load(f)
    print(f"  [Checkpoint] Loaded {len(records)} previously processed records from {path}")
    return records

def get_processed_keys(records: list) -> set:
    return {(r["claim_id"], r["q_idx"]) for r in records}

print("Checkpoint helpers defined.")
# Out:
# Checkpoint helpers defined.

# %% [markdown]
# ## 9. Updated `process_one` -- Multi-Query + Threshold + Entity Comparison
#
# Changes from previous version:
# - **Multi-query**: uses snippet splits + individual entities + question as FAISS queries
# - **Threshold logic**: evidence_source reflects swap/keep-both/fallback decision
# - **Entity extraction from chunks**: extracts entities from all chunks with score > 0.5
# - **Entity set comparison**: compares against target entities for TRUE/CONFLICTING signal
# - **Stores all retrieved chunks above mid threshold** for downstream analysis

# %%
def process_one(args):
    sid, q_idx, item, match = args
    our_q    = item["question"]
    sr_list  = item["search_results"]
    qt_q     = match["matched_qt_question"]
    m_score  = match["score"]
    top_link = sr_list[0].get("link", "") if sr_list else ""

    # Original snippet (Google provides text where query matches, with ... separators)
    original_snippet = sr_list[0].get("snippet", "") if sr_list else ""

    # Fetch article
    article_text, used_url, fetch_source = fetch_best_article(our_q, top_link, sr_list)

    # Entity extraction (question-level)
    our_ents     = scan_all_entities(our_q)
    qt_ents      = scan_all_entities(qt_q) if qt_q else []
    missing_ents = compute_missing_entities(qt_ents, our_ents)
    target_info  = extract_target_entity(our_q, qt_q or "")
    target_entity_texts = [e["text"] for e in target_info.get("entities", []) if e.get("text")]

    if article_text:
        chunks = chunk_text(article_text)
        index, chunks = build_faiss_index(chunks)

        # --- NEW: Build multi-query list ---
        # 1. Snippet splits (split original snippet by ...)
        snippet_queries = split_snippet_queries(original_snippet)
        # 2. Individual target entities as separate queries
        entity_queries  = get_entity_queries(target_info)
        # 3. Original question (for coverage)
        all_queries = [our_q] + snippet_queries + entity_queries
        # Deduplicate while preserving order
        seen_q, deduped_queries = set(), []
        for q in all_queries:
            norm_q = q.lower().strip()
            if norm_q not in seen_q:
                seen_q.add(norm_q)
                deduped_queries.append(q)

        # --- NEW: Multi-query retrieval ---
        retrieved_chunks = multi_query_retrieve(index, chunks, deduped_queries, top_k=3)

        # --- NEW: Threshold logic ---
        threshold_result = apply_threshold_logic(retrieved_chunks, original_snippet)

        # --- NEW: Entity extraction from good chunks (score > 0.5) ---
        chunk_entities = extract_entities_from_chunks(
            threshold_result["all_chunks_above_mid"],
            target_info["entity_type"]
        )

        # --- NEW: Entity set comparison ---
        entity_comparison = compare_entity_sets(target_entity_texts, chunk_entities)

    else:
        snippet_queries   = split_snippet_queries(original_snippet)
        entity_queries    = get_entity_queries(target_info) if 'target_info' in dir() else []
        deduped_queries   = []
        retrieved_chunks  = []
        threshold_result  = {
            "best_chunk": "", "best_score": 0.0,
            "primary_evidence": original_snippet,
            "evidence_source": "snippet_only",
            "all_chunks_above_mid": []
        }
        chunk_entities    = []
        entity_comparison = {"verdict": "INSUFFICIENT", "reason": "no_article",
                             "match_ratio": 0.0, "intersection": [],
                             "missing": list({e.lower() for e in target_entity_texts}),
                             "extra": []}

    # Legacy entity presence flags (kept for backward compatibility)
    top_chunk = threshold_result["best_chunk"]
    our_present,     _ = any_entity_in_text([e[0] for e in our_ents],     top_chunk)
    qt_present,      _ = any_entity_in_text([e[0] for e in qt_ents],      top_chunk)
    missing_present, _ = any_entity_in_text([e[0] for e in missing_ents], top_chunk)

    # High-level flag
    ev_verdict = entity_comparison["verdict"]
    best_score = threshold_result["best_score"]

    if not qt_q:
        flag = "NO_QT_MATCH"
    elif best_score > SCORE_HIGH and ev_verdict == "TRUE_SIGNAL":
        flag = "LIKELY_TRUE"
    elif best_score > SCORE_HIGH and ev_verdict == "CONFLICTING":
        flag = "POSSIBLY_FALSE"   # good chunk but entities missing/contradicting
    elif best_score > SCORE_MID and ev_verdict == "CONFLICTING":
        flag = "CONFLICTING"
    elif qt_present or our_present:
        flag = "TARGET_ENTITY_PRESENT"
    else:
        flag = "TARGET_ENTITY_MISSING"

    return {
        # Identification
        "claim_id":         sid,
        "claim":            claims[sid],
        "label":            labels[sid],
        "category":         categories[sid],
        "taxonomy":         taxonomy[sid],
        "q_idx":            q_idx,
        # Question matching
        "our_question":     our_q,
        "matched_qt_q":     qt_q or "",
        "match_score":      m_score,
        # Fetch info
        "used_url":         used_url or "",
        "fetch_source":     fetch_source,
        "original_snippet": original_snippet,
        # NEW: Multi-query info
        "snippet_queries":    snippet_queries,
        "entity_queries":     entity_queries,
        "num_queries_used":   len(deduped_queries),
        # NEW: Retrieval + threshold results
        "best_chunk":           threshold_result["best_chunk"],
        "best_score":           threshold_result["best_score"],
        "primary_evidence":     threshold_result["primary_evidence"],
        "evidence_source":      threshold_result["evidence_source"],
        "top_chunks_above_mid": threshold_result["all_chunks_above_mid"],
        # NEW: Entity analysis
        "target_entity":       target_info["best_entity"],
        "entity_type":         target_info["entity_type"],
        "extraction_status":   target_info["status"],
        "our_entities":        our_ents,
        "qt_entities":         qt_ents,
        "missing_entities":    missing_ents,
        "chunk_entities":      chunk_entities,
        "entity_comparison":   entity_comparison,
        # Legacy flags
        "our_present":         our_present,
        "qt_present":          qt_present,
        "missing_recovered":   missing_present,
        "flag":                flag,
    }

print("process_one (updated) defined.")
# Out:
# process_one (updated) defined.

# %% [markdown]
# ## 10. Full Pipeline with Checkpoint Saving
#
# - Loads existing checkpoint on startup (if any).
# - Skips already-processed (claim_id, q_idx) pairs.
# - Saves checkpoint every `SAVE_EVERY` newly completed records.
# - Safe to re-run after interruption -- no re-processing of completed work.

# %%
SAVE_EVERY  = 50   # checkpoint interval
MAX_WORKERS = 20   # threads for HTTP fetching

# Build full args list
all_args = [
    (sid, q_idx, item, match)
    for sid in sample_ids
    for q_idx, (item, match) in enumerate(zip(our_evidences[sid], match_results[sid]))
]

# Load checkpoint
CHECKPOINT_PATH  = "to.json"
output_records = load_checkpoint(CHECKPOINT_PATH)
processed_keys = get_processed_keys(output_records)

# Filter already-processed
remaining_args = [a for a in all_args if (a[0], a[1]) not in processed_keys]
print(f"Total: {len(all_args)}  |  Done: {len(processed_keys)}  |  Remaining: {len(remaining_args)}")

# Process
new_records = []
with concurrent.futures.ThreadPoolExecutor(max_workers=MAX_WORKERS) as executor:
    futures = {executor.submit(process_one, args): args for args in remaining_args}
    with tqdm(total=len(remaining_args), desc="Processing", unit="q") as pbar:
        for future in concurrent.futures.as_completed(futures):
            try:
                rec = future.result()
                new_records.append(rec)
                output_records.append(rec)
                if len(new_records) % SAVE_EVERY == 0:
                    save_checkpoint(output_records, CHECKPOINT_PATH)
            except Exception as e:
                args = futures[future]
                print(f"  Error claim={args[0]} q={args[1]}: {e}")
            pbar.update(1)

# Final save
save_checkpoint(output_records, "to.json")
output_records.sort(key=lambda r: (int(r["claim_id"]), r["q_idx"]))
print(f"Done. {len(output_records)} total records.")
# Out:
#   [Checkpoint] No checkpoint at to.json. Starting fresh.
# Total: 12390  |  Done: 0  |  Remaining: 12390
# Processing:   0%|          | 0/12390 [00:00<?, ?q/s]
#   [Checkpoint] Saved 50 records -> to.json
#   [Checkpoint] Saved 100 records -> to.json
#   [Checkpoint] Saved 150 records -> to.json
#   [Checkpoint] Saved 200 records -> to.json
# ERROR:trafilatura.utils:parsed tree length: 1, wrong data type or not valid HTML
# ERROR:trafilatura.core:empty HTML tree: None
#   [Checkpoint] Saved 250 records -> to.json
#   [Checkpoint] Saved 300 records -> to.json
#   [Checkpoint] Saved 350 records -> to.json
#   [Checkpoint] Saved 400 records -> to.json
#   [Checkpoint] Saved 450 records -> to.json
#   [Checkpoint] Saved 500 records -> to.json
#   [Checkpoint] Saved 550 records -> to.json
#   [Checkpoint] Saved 600 records -> to.json
#   [Checkpoint] Saved 650 records -> to.json
#   [Checkpoint] Saved 700 records -> to.json
#   [Checkpoint] Saved 750 records -> to.json
#   [Checkpoint] Saved 800 records -> to.json
#   [Checkpoint] Saved 850 records -> to.json
#   [Checkpoint] Saved 900 records -> to.json
#   [Checkpoint] Saved 950 records -> to.json
#   [Checkpoint] Saved 1000 records -> to.json
# ERROR:trafilatura.utils:parsed tree length: 0, wrong data type or not valid HTML
# ERROR:trafilatura.core:empty HTML tree: None
#   [Checkpoint] Saved 1050 records -> to.json
#   [Checkpoint] Saved 1100 records -> to.json
#   [Checkpoint] Saved 1150 records -> to.json
#   [Checkpoint] Saved 1200 records -> to.json
#   [Checkpoint] Saved 1250 records -> to.json
#   [Checkpoint] Saved 1300 records -> to.json
#   [Checkpoint] Saved 1350 records -> to.json
#   [Checkpoint] Saved 1400 records -> to.json
#   [Checkpoint] Saved 1450 records -> to.json
#   [Checkpoint] Saved 1500 records -> to.json
#   [Checkpoint] Saved 1550 records -> to.json
#   [Checkpoint] Saved 1600 records -> to.json
#   [Checkpoint] Saved 1650 records -> to.json
#   [Checkpoint] Saved 1700 records -> to.json
#   [Checkpoint] Saved 1750 records -> to.json
#   [Checkpoint] Saved 1800 records -> to.json
#   [Checkpoint] Saved 1850 records -> to.json
#   [Checkpoint] Saved 1900 records -> to.json
#   [Checkpoint] Saved 1950 records -> to.json
#   [Checkpoint] Saved 2000 records -> to.json
#   [Checkpoint] Saved 2050 records -> to.json
#   [Checkpoint] Saved 2100 records -> to.json
#   [Checkpoint] Saved 2150 records -> to.json
#   [Checkpoint] Saved 2200 records -> to.json
#   [Checkpoint] Saved 2250 records -> to.json
#   [Checkpoint] Saved 2300 records -> to.json
# ERROR:trafilatura.utils:parsed tree length: 0, wrong data type or not valid HTML
# ERROR:trafilatura.core:empty HTML tree: None
#   [Checkpoint] Saved 2350 records -> to.json
#   [Checkpoint] Saved 2400 records -> to.json
#   [Checkpoint] Saved 2450 records -> to.json
#   [Checkpoint] Saved 2500 records -> to.json
#   [Checkpoint] Saved 2550 records -> to.json
#   [Checkpoint] Saved 2600 records -> to.json
#   [Checkpoint] Saved 2650 records -> to.json
#   [Checkpoint] Saved 2700 records -> to.json
#   [Checkpoint] Saved 2750 records -> to.json
#   [Checkpoint] Saved 2800 records -> to.json
#   [Checkpoint] Saved 2850 records -> to.json
#   [Checkpoint] Saved 2900 records -> to.json
#   [Checkpoint] Saved 2950 records -> to.json
#   [Checkpoint] Saved 3000 records -> to.json
#   [Checkpoint] Saved 3050 records -> to.json
#   [Checkpoint] Saved 3100 records -> to.json
#   [Checkpoint] Saved 3150 records -> to.json
#   [Checkpoint] Saved 3200 records -> to.json
#   [Checkpoint] Saved 3250 records -> to.json
# ERROR:trafilatura.utils:parsed tree length: 1, wrong data type or not valid HTML
# ERROR:trafilatura.core:empty HTML tree: None
#   [Checkpoint] Saved 3300 records -> to.json
#   [Checkpoint] Saved 3350 records -> to.json
#   [Checkpoint] Saved 3400 records -> to.json
#   [Checkpoint] Saved 3450 records -> to.json
#   [Checkpoint] Saved 3500 records -> to.json
#   [Checkpoint] Saved 3550 records -> to.json
# ERROR:trafilatura.utils:parsed tree length: 1, wrong data type or not valid HTML
# ERROR:trafilatura.core:empty HTML tree: None
#   [Checkpoint] Saved 3600 records -> to.json
#   [Checkpoint] Saved 3650 records -> to.json
#   [Checkpoint] Saved 3700 records -> to.json
#   [Checkpoint] Saved 3750 records -> to.json
#   [Checkpoint] Saved 3800 records -> to.json
#   [Checkpoint] Saved 3850 records -> to.json
#   [Checkpoint] Saved 3900 records -> to.json
#   [Checkpoint] Saved 3950 records -> to.json
#   [Checkpoint] Saved 4000 records -> to.json
#   [Checkpoint] Saved 4050 records -> to.json
#   [Checkpoint] Saved 4100 records -> to.json
#   [Checkpoint] Saved 4150 records -> to.json
#   [Checkpoint] Saved 4200 records -> to.json
# ERROR:trafilatura.utils:parsed tree length: 1, wrong data type or not valid HTML
# ERROR:trafilatura.core:empty HTML tree: None
#   [Checkpoint] Saved 4250 records -> to.json
#   [Checkpoint] Saved 4300 records -> to.json
#   [Checkpoint] Saved 4350 records -> to.json
#   [Checkpoint] Saved 4400 records -> to.json
#   [Checkpoint] Saved 4450 records -> to.json
#   [Checkpoint] Saved 4500 records -> to.json
#   [Checkpoint] Saved 4550 records -> to.json
#   [Checkpoint] Saved 4600 records -> to.json
#   [Checkpoint] Saved 4650 records -> to.json
#   [Checkpoint] Saved 4700 records -> to.json
#   [Checkpoint] Saved 4750 records -> to.json
#   [Checkpoint] Saved 4800 records -> to.json
#   [Checkpoint] Saved 4850 records -> to.json
#   [Checkpoint] Saved 4900 records -> to.json
#   [Checkpoint] Saved 4950 records -> to.json
#   [Checkpoint] Saved 5000 records -> to.json
#   [Checkpoint] Saved 5050 records -> to.json
#   [Checkpoint] Saved 5100 records -> to.json
#   [Checkpoint] Saved 5150 records -> to.json
#   [Checkpoint] Saved 5200 records -> to.json
#   [Checkpoint] Saved 5250 records -> to.json
#   [Checkpoint] Saved 5300 records -> to.json
#   [Checkpoint] Saved 5350 records -> to.json
#   [Checkpoint] Saved 5400 records -> to.json
#   [Checkpoint] Saved 5450 records -> to.json
#   [Checkpoint] Saved 5500 records -> to.json
# ERROR:trafilatura.utils:parsed tree length: 1, wrong data type or not valid HTML
# ERROR:trafilatura.core:empty HTML tree: None
#   [Checkpoint] Saved 5550 records -> to.json
#   [Checkpoint] Saved 5600 records -> to.json
#   [Checkpoint] Saved 5650 records -> to.json
#   [Checkpoint] Saved 5700 records -> to.json
#   [Checkpoint] Saved 5750 records -> to.json
#   [Checkpoint] Saved 5800 records -> to.json
#   [Checkpoint] Saved 5850 records -> to.json
#   [Checkpoint] Saved 5900 records -> to.json
#   [Checkpoint] Saved 5950 records -> to.json
#   [Checkpoint] Saved 6000 records -> to.json
#   [Checkpoint] Saved 6050 records -> to.json
#   [Checkpoint] Saved 6100 records -> to.json
# ERROR:trafilatura.utils:parsed tree length: 1, wrong data type or not valid HTML
# ERROR:trafilatura.core:empty HTML tree: None
#   [Checkpoint] Saved 6150 records -> to.json
#   [Checkpoint] Saved 6200 records -> to.json
#   [Checkpoint] Saved 6250 records -> to.json
#   [Checkpoint] Saved 6300 records -> to.json
#   [Checkpoint] Saved 6350 records -> to.json
#   [Checkpoint] Saved 6400 records -> to.json
#   [Checkpoint] Saved 6450 records -> to.json
#   [Checkpoint] Saved 6500 records -> to.json
#   [Checkpoint] Saved 6550 records -> to.json
#   [Checkpoint] Saved 6600 records -> to.json
#   [Checkpoint] Saved 6650 records -> to.json
#   [Checkpoint] Saved 6700 records -> to.json
#   [Checkpoint] Saved 6750 records -> to.json
#   [Checkpoint] Saved 6800 records -> to.json
#   [Checkpoint] Saved 6850 records -> to.json
#   [Checkpoint] Saved 6900 records -> to.json
#   [Checkpoint] Saved 6950 records -> to.json
#   [Checkpoint] Saved 7000 records -> to.json
#   [Checkpoint] Saved 7050 records -> to.json
#   [Checkpoint] Saved 7100 records -> to.json
#   [Checkpoint] Saved 7150 records -> to.json
#   [Checkpoint] Saved 7200 records -> to.json
#   [Checkpoint] Saved 7250 records -> to.json
#   [Checkpoint] Saved 7300 records -> to.json
#   [Checkpoint] Saved 7350 records -> to.json
#   [Checkpoint] Saved 7400 records -> to.json
#   [Checkpoint] Saved 7450 records -> to.json
#   [Checkpoint] Saved 7500 records -> to.json
#   [Checkpoint] Saved 7550 records -> to.json
#   [Checkpoint] Saved 7600 records -> to.json
#   [Checkpoint] Saved 7650 records -> to.json
#   [Checkpoint] Saved 7700 records -> to.json
#   [Checkpoint] Saved 7750 records -> to.json
#   [Checkpoint] Saved 7800 records -> to.json
#   [Checkpoint] Saved 7850 records -> to.json
#   [Checkpoint] Saved 7900 records -> to.json
# ERROR:trafilatura.utils:parsed tree length: 1, wrong data type or not valid HTML
# ERROR:trafilatura.core:empty HTML tree: None
#   [Checkpoint] Saved 7950 records -> to.json
#   [Checkpoint] Saved 8000 records -> to.json
#   [Checkpoint] Saved 8050 records -> to.json
#   [Checkpoint] Saved 8100 records -> to.json
#   [Checkpoint] Saved 8150 records -> to.json
#   [Checkpoint] Saved 8200 records -> to.json
#   [Checkpoint] Saved 8250 records -> to.json
#   [Checkpoint] Saved 8300 records -> to.json
#   [Checkpoint] Saved 8350 records -> to.json
#   [Checkpoint] Saved 8400 records -> to.json
#   [Checkpoint] Saved 8450 records -> to.json
#   [Checkpoint] Saved 8500 records -> to.json
#   [Checkpoint] Saved 8550 records -> to.json
#   [Checkpoint] Saved 8600 records -> to.json
#   [Checkpoint] Saved 8650 records -> to.json
#   [Checkpoint] Saved 8700 records -> to.json
#   [Checkpoint] Saved 8750 records -> to.json
#   [Checkpoint] Saved 8800 records -> to.json
#   [Checkpoint] Saved 8850 records -> to.json
#   [Checkpoint] Saved 8900 records -> to.json
#   [Checkpoint] Saved 8950 records -> to.json
# ERROR:trafilatura.utils:parsed tree length: 0, wrong data type or not valid HTML
# ERROR:trafilatura.core:empty HTML tree: None
#   [Checkpoint] Saved 9000 records -> to.json
#   [Checkpoint] Saved 9050 records -> to.json
# ERROR:trafilatura.utils:parsed tree length: 0, wrong data type or not valid HTML
# ERROR:trafilatura.core:empty HTML tree: None
#   [Checkpoint] Saved 9100 records -> to.json
#   [Checkpoint] Saved 9150 records -> to.json
#   [Checkpoint] Saved 9200 records -> to.json
#   [Checkpoint] Saved 9250 records -> to.json
#   [Checkpoint] Saved 9300 records -> to.json
#   [Checkpoint] Saved 9350 records -> to.json
#   [Checkpoint] Saved 9400 records -> to.json
#   [Checkpoint] Saved 9450 records -> to.json
#   [Checkpoint] Saved 9500 records -> to.json
#   [Checkpoint] Saved 9550 records -> to.json
#   [Checkpoint] Saved 9600 records -> to.json
#   [Checkpoint] Saved 9650 records -> to.json
#   [Checkpoint] Saved 9700 records -> to.json
#   [Checkpoint] Saved 9750 records -> to.json
#   [Checkpoint] Saved 9800 records -> to.json
#   [Checkpoint] Saved 9850 records -> to.json
#   [Checkpoint] Saved 9900 records -> to.json
#   [Checkpoint] Saved 9950 records -> to.json
#   [Checkpoint] Saved 10000 records -> to.json
#   [Checkpoint] Saved 10050 records -> to.json
#   [Checkpoint] Saved 10100 records -> to.json
#   [Checkpoint] Saved 10150 records -> to.json
#   [Checkpoint] Saved 10200 records -> to.json
#   [Checkpoint] Saved 10250 records -> to.json
#   [Checkpoint] Saved 10300 records -> to.json
#   [Checkpoint] Saved 10350 records -> to.json
#   [Checkpoint] Saved 10400 records -> to.json
#   [Checkpoint] Saved 10450 records -> to.json
#   [Checkpoint] Saved 10500 records -> to.json
#   [Checkpoint] Saved 10550 records -> to.json
#   [Checkpoint] Saved 10600 records -> to.json
#   [Checkpoint] Saved 10650 records -> to.json
#   [Checkpoint] Saved 10700 records -> to.json
#   [Checkpoint] Saved 10750 records -> to.json
#   [Checkpoint] Saved 10800 records -> to.json
#   [Checkpoint] Saved 10850 records -> to.json
#   [Checkpoint] Saved 10900 records -> to.json
#   [Checkpoint] Saved 10950 records -> to.json
#   [Checkpoint] Saved 11000 records -> to.json
#   [Checkpoint] Saved 11050 records -> to.json
#   [Checkpoint] Saved 11100 records -> to.json
#   [Checkpoint] Saved 11150 records -> to.json
#   [Checkpoint] Saved 11200 records -> to.json
#   [Checkpoint] Saved 11250 records -> to.json
#   [Checkpoint] Saved 11300 records -> to.json
#   [Checkpoint] Saved 11350 records -> to.json
#   [Checkpoint] Saved 11400 records -> to.json
#   [Checkpoint] Saved 11450 records -> to.json
#   [Checkpoint] Saved 11500 records -> to.json
# ERROR:trafilatura.utils:parsed tree length: 0, wrong data type or not valid HTML
# ERROR:trafilatura.core:empty HTML tree: None
#   [Checkpoint] Saved 11550 records -> to.json
#   [Checkpoint] Saved 11600 records -> to.json
#   [Checkpoint] Saved 11650 records -> to.json
#   [Checkpoint] Saved 11700 records -> to.json
#   [Checkpoint] Saved 11750 records -> to.json
#   [Checkpoint] Saved 11800 records -> to.json
#   [Checkpoint] Saved 11850 records -> to.json
#   [Checkpoint] Saved 11900 records -> to.json
#   [Checkpoint] Saved 11950 records -> to.json
#   [Checkpoint] Saved 12000 records -> to.json
#   [Checkpoint] Saved 12050 records -> to.json
#   [Checkpoint] Saved 12100 records -> to.json
#   [Checkpoint] Saved 12150 records -> to.json
#   [Checkpoint] Saved 12200 records -> to.json
#   [Checkpoint] Saved 12250 records -> to.json
#   [Checkpoint] Saved 12300 records -> to.json
#   [Checkpoint] Saved 12350 records -> to.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1285/977370276.py in <cell line: 0>()
#      36
#      37 # Final save
# ---> 38 save_checkpoint(output_records, "/content/drive/MyDrive/claim_verification_analysis_updated_v2/checkpoint_records.json")
#      39 output_records.sort(key=lambda r: (int(r["claim_id"]), r["q_idx"]))
#      40 print(f"Done. {len(output_records)} total records.")
#
# /tmp/ipykernel_1285/2728577640.py in save_checkpoint(records, path)
#       1 def save_checkpoint(records: list, path: str = CHECKPOINT_PATH):
# ----> 2     with open(path, "w") as f:
#       3         json.dump(records, f, indent=2)
#       4     print(f"  [Checkpoint] Saved {len(records)} records -> {path}")
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/claim_verification_analysis_updated_v2/checkpoint_records.json'

# %%
# Final save
save_checkpoint(output_records, "to.json")
output_records.sort(key=lambda r: (int(r["claim_id"]), r["q_idx"]))
print(f"Done. {len(output_records)} total records.")
# Out:
#   [Checkpoint] Saved 12390 records -> to.json
# Done. 12390 total records.

# %%
d2 = pd.read_json("/content/checkpoint_records_merged.json")
d2
# Out:
#        claim_id                                              claim  \
# 0             0  "The non-partisan Congressional Budget Office ...
# 1             0  "The non-partisan Congressional Budget Office ...
# 2             0  "The non-partisan Congressional Budget Office ...
# 3             1  "More than 50 percent of immigrants from (El S...
# 4             1  "More than 50 percent of immigrants from (El S...
# ...         ...                                                ...
# 46429     15476  A recent study found "that cities where Uber o...
# 46430     15476  A recent study found "that cities where Uber o...
# 46431     15477  The Biden administration "published a study co...
# 46432     15477  The Biden administration "published a study co...
# 46433     15477  The Biden administration "published a study co...
#
#                  label    category     taxonomy  q_idx  \
# 0          Conflicting        test  Statistical      0
# 1          Conflicting        test  Statistical      1
# 2          Conflicting        test  Statistical      2
# 3                 True        test  Statistical      0
# 4                 True        test  Statistical      1
# ...                ...         ...          ...    ...
# 46429  Half True/False  validation   Comparison      1
# 46430  Half True/False  validation   Comparison      2
# 46431             True  validation  Statistical      0
# 46432             True  validation  Statistical      1
# 46433             True  validation  Statistical      2
#
#                                             our_question  \
# 0      Who concluded ObamaCare will cost the U.S. 800...
# 1      Which program will cost the U.S. more than 800...
# 2       Which ObamaCare will cost the U.S. 800,000 jobs?
# 3      Which country has over 50 percent of immigrant...
# 4      Which program is used by at least half of immi...
# ...                                                  ...
# 46429  Which city has 3.6%-5.6% fewer drunk driving d...
# 46430  Which city has 3,6%-5.6% fewer drunk driving d...
# 46431  Which of the 5 new cars on the road by 2050 wi...
# 46432  Which of the five new cars will require liquid...
# 46433  Which of the new cars on the road by 2050 will...
#
#                                             matched_qt_q  match_score  \
# 0      did the congressional budget office conclude t...       0.9029
# 1      did the congressional budget office conclude t...       0.6259
# 2      is there evidence to support the claim that ob...       0.8111
# 3      do more than 50 percent of immigrants from gua...       0.7681
# 4      do more than 50 percent of immigrants from el ...       0.7716
# ...                                                  ...          ...
# 46429  did the study find that cities with uber have ...       0.7740
# 46430  did the study find that cities with uber have ...       0.8478
# 46431  does the study conclude that 4 out of 5 new ca...       0.8793
# 46432  does the study conclude that 4 out of 5 new ca...       0.7778
# 46433  does the study conclude that 4 out of 5 new ca...       0.8705
#
#                                                 used_url  ...  \
# 0      https://www.lgraham.senate.gov/public/index.cf...  ...
# 1      https://www.coalitionfortheamericandream.us/da...  ...
# 2      https://edworkforce.house.gov/news/documentsin...  ...
# 3                  https://www.fns.usda.gov/snap/history  ...
# 4      https://www.americanimmigrationcouncil.org/fac...  ...
# ...                                                  ...  ...
# 46429                                                     ...
# 46430  https://nap.nationalacademies.org/read/21875/c...  ...
# 46431                                                     ...
# 46432  https://newscenter.lbl.gov/2024/08/29/five-way...  ...
# 46433                                                     ...
#
#       extraction_status                                       our_entities  \
# 0        FALLBACK_LABEL  [[Who, person], [ObamaCare, law], [U.S., count...
# 1        FALLBACK_LABEL  [[U.S., country], [more than 800,000 jobs, num...
# 2                    OK  [[ObamaCare, law], [U.S., country], [800,000, ...
# 3           FALLBACK_NP  [[country, country], [over 50 percent, percent...
# 4        FALLBACK_LABEL  [[at least half, percentage], [immigrants, per...
# ...                 ...                                                ...
# 46429    FALLBACK_LABEL  [[city, location], [3.6%, percentage], [5.6%, ...
# 46430    FALLBACK_LABEL  [[city, location], [3,6%, percentage], [5.6%, ...
# 46431    FALLBACK_LABEL                [[new cars, product], [2050, date]]
# 46432    FALLBACK_LABEL  [[five new cars, number], [liquid fuels, produ...
# 46433    FALLBACK_LABEL                [[new cars, product], [2050, date]]
#
#                                              qt_entities  \
# 0      [[congressional budget office, government], [o...
# 1      [[congressional budget office, government], [o...
# 2      [[obamacare, product], [u.s., country], [more ...
# 3      [[50 percent, percentage], [immigrants, person...
# 4      [[50 percent, percentage], [immigrants, person...
# ...                                                  ...
# 46429  [[cities, location], [uber, product], [lower r...
# 46430  [[cities, location], [uber, product], [lower r...
# 46431  [[4 out of 5, number], [new cars, product], [o...
# 46432  [[4 out of 5, number], [new cars, product], [o...
# 46433  [[4 out of 5, number], [new cars, product], [o...
#
#                                         missing_entities  \
# 0            [[congressional budget office, government]]
# 1      [[congressional budget office, government], [o...
# 2                                                     []
# 3      [[guatemala, country], [use at least one major...
# 4      [[50 percent, percentage], [use at least one m...
# ...                                                  ...
# 46429        [[uber, product], [lower rate, percentage]]
# 46430     [[cities, location], [lower rate, percentage]]
# 46431  [[4 out of 5, number], [on the road, location]...
# 46432  [[4 out of 5, number], [on the road, location]...
# 46433  [[4 out of 5, number], [on the road, location]...
#
#                                           chunk_entities  \
# 0      [{'text': 'Congressional Budget Office', 'labe...
# 1                                                     []
# 2      [{'text': 'Supreme Court', 'label': 'organizat...
# 3                                                     []
# 4      [{'text': 'Temporary Protected Status (TPS)', ...
# ...                                                  ...
# 46429                                                 []
# 46430  [{'text': 'Subramanian', 'label': 'person', 's...
# 46431                                                 []
# 46432  [{'text': 'liquid fuels', 'label': 'product', ...
# 46433                                                 []
#
#                                        entity_comparison  our_present  \
# 0      {'verdict': 'TRUE_SIGNAL', 'reason': 'entities...         True
# 1      {'verdict': 'CONFLICTING', 'reason': 'no_match...        False
# 2      {'verdict': 'CONFLICTING', 'reason': 'partial_...        False
# 3      {'verdict': 'CONFLICTING', 'reason': 'no_match...        False
# 4      {'verdict': 'CONFLICTING', 'reason': 'no_match...         True
# ...                                                  ...          ...
# 46429  {'verdict': 'INSUFFICIENT', 'reason': 'no_arti...        False
# 46430  {'verdict': 'CONFLICTING', 'reason': 'partial_...         True
# 46431  {'verdict': 'INSUFFICIENT', 'reason': 'no_arti...        False
# 46432  {'verdict': 'CONFLICTING', 'reason': 'partial_...         True
# 46433  {'verdict': 'INSUFFICIENT', 'reason': 'no_arti...        False
#
#       qt_present missing_recovered                   flag
# 0           True              True  TARGET_ENTITY_PRESENT
# 1          False             False  TARGET_ENTITY_MISSING
# 2          False             False            CONFLICTING
# 3          False             False  TARGET_ENTITY_MISSING
# 4          False             False            CONFLICTING
# ...          ...               ...                    ...
# 46429      False             False  TARGET_ENTITY_MISSING
# 46430       True              True            CONFLICTING
# 46431      False             False  TARGET_ENTITY_MISSING
# 46432       True             False            CONFLICTING
# 46433      False             False  TARGET_ENTITY_MISSING
#
# [46434 rows x 32 columns]

# %%
d3 = d2[d2.taxonomy != 'Temporal']
d3
# Out:
#        claim_id                                              claim  \
# 0             0  "The non-partisan Congressional Budget Office ...
# 1             0  "The non-partisan Congressional Budget Office ...
# 2             0  "The non-partisan Congressional Budget Office ...
# 3             1  "More than 50 percent of immigrants from (El S...
# 4             1  "More than 50 percent of immigrants from (El S...
# ...         ...                                                ...
# 46429     15476  A recent study found "that cities where Uber o...
# 46430     15476  A recent study found "that cities where Uber o...
# 46431     15477  The Biden administration "published a study co...
# 46432     15477  The Biden administration "published a study co...
# 46433     15477  The Biden administration "published a study co...
#
#                  label    category     taxonomy  q_idx  \
# 0          Conflicting        test  Statistical      0
# 1          Conflicting        test  Statistical      1
# 2          Conflicting        test  Statistical      2
# 3                 True        test  Statistical      0
# 4                 True        test  Statistical      1
# ...                ...         ...          ...    ...
# 46429  Half True/False  validation   Comparison      1
# 46430  Half True/False  validation   Comparison      2
# 46431             True  validation  Statistical      0
# 46432             True  validation  Statistical      1
# 46433             True  validation  Statistical      2
#
#                                             our_question  \
# 0      Who concluded ObamaCare will cost the U.S. 800...
# 1      Which program will cost the U.S. more than 800...
# 2       Which ObamaCare will cost the U.S. 800,000 jobs?
# 3      Which country has over 50 percent of immigrant...
# 4      Which program is used by at least half of immi...
# ...                                                  ...
# 46429  Which city has 3.6%-5.6% fewer drunk driving d...
# 46430  Which city has 3,6%-5.6% fewer drunk driving d...
# 46431  Which of the 5 new cars on the road by 2050 wi...
# 46432  Which of the five new cars will require liquid...
# 46433  Which of the new cars on the road by 2050 will...
#
#                                             matched_qt_q  match_score  \
# 0      did the congressional budget office conclude t...       0.9029
# 1      did the congressional budget office conclude t...       0.6259
# 2      is there evidence to support the claim that ob...       0.8111
# 3      do more than 50 percent of immigrants from gua...       0.7681
# 4      do more than 50 percent of immigrants from el ...       0.7716
# ...                                                  ...          ...
# 46429  did the study find that cities with uber have ...       0.7740
# 46430  did the study find that cities with uber have ...       0.8478
# 46431  does the study conclude that 4 out of 5 new ca...       0.8793
# 46432  does the study conclude that 4 out of 5 new ca...       0.7778
# 46433  does the study conclude that 4 out of 5 new ca...       0.8705
#
#                                                 used_url  ...  \
# 0      https://www.lgraham.senate.gov/public/index.cf...  ...
# 1      https://www.coalitionfortheamericandream.us/da...  ...
# 2      https://edworkforce.house.gov/news/documentsin...  ...
# 3                  https://www.fns.usda.gov/snap/history  ...
# 4      https://www.americanimmigrationcouncil.org/fac...  ...
# ...                                                  ...  ...
# 46429                                                     ...
# 46430  https://nap.nationalacademies.org/read/21875/c...  ...
# 46431                                                     ...
# 46432  https://newscenter.lbl.gov/2024/08/29/five-way...  ...
# 46433                                                     ...
#
#       extraction_status                                       our_entities  \
# 0        FALLBACK_LABEL  [[Who, person], [ObamaCare, law], [U.S., count...
# 1        FALLBACK_LABEL  [[U.S., country], [more than 800,000 jobs, num...
# 2                    OK  [[ObamaCare, law], [U.S., country], [800,000, ...
# 3           FALLBACK_NP  [[country, country], [over 50 percent, percent...
# 4        FALLBACK_LABEL  [[at least half, percentage], [immigrants, per...
# ...                 ...                                                ...
# 46429    FALLBACK_LABEL  [[city, location], [3.6%, percentage], [5.6%, ...
# 46430    FALLBACK_LABEL  [[city, location], [3,6%, percentage], [5.6%, ...
# 46431    FALLBACK_LABEL                [[new cars, product], [2050, date]]
# 46432    FALLBACK_LABEL  [[five new cars, number], [liquid fuels, produ...
# 46433    FALLBACK_LABEL                [[new cars, product], [2050, date]]
#
#                                              qt_entities  \
# 0      [[congressional budget office, government], [o...
# 1      [[congressional budget office, government], [o...
# 2      [[obamacare, product], [u.s., country], [more ...
# 3      [[50 percent, percentage], [immigrants, person...
# 4      [[50 percent, percentage], [immigrants, person...
# ...                                                  ...
# 46429  [[cities, location], [uber, product], [lower r...
# 46430  [[cities, location], [uber, product], [lower r...
# 46431  [[4 out of 5, number], [new cars, product], [o...
# 46432  [[4 out of 5, number], [new cars, product], [o...
# 46433  [[4 out of 5, number], [new cars, product], [o...
#
#                                         missing_entities  \
# 0            [[congressional budget office, government]]
# 1      [[congressional budget office, government], [o...
# 2                                                     []
# 3      [[guatemala, country], [use at least one major...
# 4      [[50 percent, percentage], [use at least one m...
# ...                                                  ...
# 46429        [[uber, product], [lower rate, percentage]]
# 46430     [[cities, location], [lower rate, percentage]]
# 46431  [[4 out of 5, number], [on the road, location]...
# 46432  [[4 out of 5, number], [on the road, location]...
# 46433  [[4 out of 5, number], [on the road, location]...
#
#                                           chunk_entities  \
# 0      [{'text': 'Congressional Budget Office', 'labe...
# 1                                                     []
# 2      [{'text': 'Supreme Court', 'label': 'organizat...
# 3                                                     []
# 4      [{'text': 'Temporary Protected Status (TPS)', ...
# ...                                                  ...
# 46429                                                 []
# 46430  [{'text': 'Subramanian', 'label': 'person', 's...
# 46431                                                 []
# 46432  [{'text': 'liquid fuels', 'label': 'product', ...
# 46433                                                 []
#
#                                        entity_comparison  our_present  \
# 0      {'verdict': 'TRUE_SIGNAL', 'reason': 'entities...         True
# 1      {'verdict': 'CONFLICTING', 'reason': 'no_match...        False
# 2      {'verdict': 'CONFLICTING', 'reason': 'partial_...        False
# 3      {'verdict': 'CONFLICTING', 'reason': 'no_match...        False
# 4      {'verdict': 'CONFLICTING', 'reason': 'no_match...         True
# ...                                                  ...          ...
# 46429  {'verdict': 'INSUFFICIENT', 'reason': 'no_arti...        False
# 46430  {'verdict': 'CONFLICTING', 'reason': 'partial_...         True
# 46431  {'verdict': 'INSUFFICIENT', 'reason': 'no_arti...        False
# 46432  {'verdict': 'CONFLICTING', 'reason': 'partial_...         True
# 46433  {'verdict': 'INSUFFICIENT', 'reason': 'no_arti...        False
#
#       qt_present missing_recovered                   flag
# 0           True              True  TARGET_ENTITY_PRESENT
# 1          False             False  TARGET_ENTITY_MISSING
# 2          False             False            CONFLICTING
# 3          False             False  TARGET_ENTITY_MISSING
# 4          False             False            CONFLICTING
# ...          ...               ...                    ...
# 46429      False             False  TARGET_ENTITY_MISSING
# 46430       True              True            CONFLICTING
# 46431      False             False  TARGET_ENTITY_MISSING
# 46432       True             False            CONFLICTING
# 46433      False             False  TARGET_ENTITY_MISSING
#
# [33855 rows x 32 columns]

# %%
d3.to_json("checkpoint_records_merged1.json", orient='records', indent=2)

# %%
import json
import os

def load_records_from_file(filepath):
    """Loads records from a JSON file, returning an empty list if the file doesn't exist."""
    if os.path.exists(filepath):
        try:
            with open(filepath, "r") as f:
                return json.load(f)
        except json.JSONDecodeError:
            print(f"Warning: Could not decode JSON from {filepath}. Returning empty list.")
            return []
    return []

# Define the paths to the two checkpoint files
file1_path = "to.json"
merged_file_path = "/content/checkpoint_records (1).json"
file2_path = "/content/checkpoint_records_merged1.json"

print(f"Loading records from: {file1_path}")
records1 = load_records_from_file(file1_path)
print(f"Loaded {len(records1)} records from file 1.")

print(f"Loading records from: {file2_path}")
records2 = load_records_from_file(file2_path)
print(f"Loaded {len(records2)} records from file 2.")

# Combine records and deduplicate based on (claim_id, q_idx)
# We'll use a dictionary to maintain uniqueness, with later records potentially overwriting earlier ones
# if they have the same key. To ensure "without losing information", we'll prioritize adding all unique.

merged_records_map = {}

for record in records1:
    key = (record["claim_id"], record["q_idx"])
    merged_records_map[key] = record

for record in records2:
    key = (record["claim_id"], record["q_idx"])
    if key not in merged_records_map: # Add only if not already present
        merged_records_map[key] = record

deduplicated_records = list(merged_records_map.values())

print(f"Total unique records after merging and deduplicating: {len(deduplicated_records)}")

# Sort the records for consistent output (optional but good practice)
deduplicated_records.sort(key=lambda r: (int(r["claim_id"]), r["q_idx"]))

# Save the merged and deduplicated records to the new file
with open(merged_file_path, "w") as f:
    json.dump(deduplicated_records, f, indent=2)

print(f"Merged records successfully saved to '{merged_file_path}'")
# Out:
# Loading records from: to.json
# Loaded 12390 records from file 1.
# Loading records from: /content/checkpoint_records_merged1.json
# Loaded 33855 records from file 2.
# Total unique records after merging and deduplicating: 46245
# Merged records successfully saved to '/content/checkpoint_records (1).json'

# %% [markdown]
# ## 11. NEW -- Empirical Analysis: Snippet vs Retrieved Chunk
#
# **From meeting:** Before finalising the evidence-swapping logic, sample 10-20 cases with
# similarity >= 0.6 or >= 0.7 and manually compare the original snippet vs the retrieved chunk.
#
# **Key observation (Yellowstone example):** A chunk with 0.7+ score can *contradict* the claim.
# This is GOOD -- semantic similarity means contextual relevance, not truth.
# A contradicting chunk with high similarity is valuable evidence for fact-checking (confirms FALSE).
#
# Run this cell first, inspect the output, then decide on thresholds.

# %%
import pandas as pd

output_records = load_checkpoint('/content/checkpoint_records (1).json')
df_analysis = pd.DataFrame(output_records)

HIGH_SIM_THRESHOLD = 0.6   # change to 0.7 to focus on clearest cases

high_sim_df = df_analysis[df_analysis["best_score"] >= HIGH_SIM_THRESHOLD].copy()
print(f"Cases with chunk score >= {HIGH_SIM_THRESHOLD}: {len(high_sim_df)}")

sample_n = min(20, len(high_sim_df))
sample_df = high_sim_df.sample(n=sample_n, random_state=42) if len(high_sim_df) >= sample_n else high_sim_df
print(f"Sampled {len(sample_df)} cases for manual review")

for i, (_, row) in enumerate(sample_df.iterrows(), 1):
    print(f"\n{'='*80}")
    print(f"Case {i}/{len(sample_df)}")
    print(f"Claim ID: {row['claim_id']}  |  Label: {row['label']}  |  Chunk Score: {row['best_score']:.3f}")
    print(f"Claim:    {row['claim']}")
    print(f"Question: {row['our_question']}")
    print(f"Evidence Source: {row['evidence_source']}")

    print(f"\n--- Original Snippet ---")
    print(row.get('original_snippet') or '[empty]')

    print(f"\n--- Retrieved Chunk (score={row['best_score']:.3f}) ---")
    print(row.get('best_chunk') or '[no chunk retrieved - below threshold]')

    ec = row.get('entity_comparison') or {}
    if isinstance(ec, dict):
        print(f"\n--- Entity Comparison ---")
        print(f"  Verdict:    {ec.get('verdict','')}")
        print(f"  Reason:     {ec.get('reason','')}")
        print(f"  Matching:   {ec.get('intersection','')}")
        print(f"  Missing:    {ec.get('missing','')}")

    print(f"\n--- Flag: {row['flag']} ---")
    print(f"  Snippet queries used: {row.get('snippet_queries', [])}")
    print(f"  Entity queries used:  {row.get('entity_queries', [])}")
    print(f"  Total queries:        {row.get('num_queries_used', 0)}")
# Out:
#   [Checkpoint] Loaded 46245 previously processed records from /content/checkpoint_records (1).json
# Cases with chunk score >= 0.6: 28941
# Sampled 20 cases for manual review
#
# ================================================================================
# Case 1/20
# Claim ID: 7189  |  Label: False  |  Chunk Score: 0.887
# Claim:    Deaths counted as Covid-19 related within 20 days of contracting the virus, no matter what other factors were involved?
# Question: Which disease was involved in more than half of the deaths?
# Evidence Source: chunk_only
#
# --- Original Snippet ---
# Jul 5, 2024 ... Centers for Disease ... More than half of firearm-related deaths were suicides and more than four out of every 10 were firearm homicides.
#
# --- Retrieved Chunk (score=0.887) ---
# More than half of firearm-related deaths were suicides and more than four out of every 10 were firearm homicides.1 More people suffer nonfatal firearm-related injuries than die. More than seven out of every 10 medically treated firearm injuries are from firearm-related assaults. Nearly two out of every 10 are from unintentional firearm injuries.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['deaths']
#
# --- Flag: POSSIBLY_FALSE ---
#   Snippet queries used: ['Jul 5, 2024', 'Centers for Disease', 'More than half of firearm-related deaths were suicides and more than four out of every 10 were firearm homicides.']
#   Entity queries used:  ['deaths']
#   Total queries:        5
#
# ================================================================================
# Case 2/20
# Claim ID: 8648  |  Label: Half True/False  |  Chunk Score: 0.647
# Claim:    In 2018, the UK contributed £11 billion to the EU and received EU funding of £6 billion.
# Question: In 2018, which country contributed £11 billion to the EU?
# Evidence Source: chunk_and_snippet
#
# --- Original Snippet ---
# In 2024, they contributed €31.7 billion from public sources and mobilised an additional €11 billion in private finance to support developing countries in ...
#
# --- Retrieved Chunk (score=0.647) ---
# This included £2.2 billion that came through the Agricultural Guarantee Fund and £0.7 billion that came back through the European Regional Development Fund. Given these figures, the ONS reports that the UK government's net contribution to the EU – that is, the difference between the money it paid to the EU and the money it received – was £11.0 billion in 2018 compared with the £20.0 billion theoretical liability. Embed code But is there anything else we might consider? Some have argued that there are other payments that should be considered.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     partial_match_entities_missing
#   Matching:   ['uk']
#   Missing:    ['the eu']
#
# --- Flag: CONFLICTING ---
#   Snippet queries used: ['In 2024, they contributed €31.7 billion from public sources and mobilised an additional €11 billion in private finance to support developing countries in']
#   Entity queries used:  ['the eu', 'uk']
#   Total queries:        4
#
# ================================================================================
# Case 3/20
# Claim ID: 847  |  Label: Conflicting  |  Chunk Score: 0.839
# Claim:    "One in 13 Black Americans are deprived of the right to vote."
# Question: Who is deprived of the right to vote?
# Evidence Source: chunk_and_snippet
#
# --- Original Snippet ---
# Jul 17, 2018 ... “No one should be deprived of their right to vote because of their disabilities. Persons with intellectual and psychosocial disabilities are no exception.”
#
# --- Retrieved Chunk (score=0.839) ---
# “Depriving persons of the right to vote on the basis of disability is contrary to these standards”, the Commissioner writes in the document, and adds that this includes cases where a judge makes an assessment of the person’s cognitive capacity or mental health status: “In a modern democracy no one needs to justify why they vote for a particular party or candidate.” In the document, the Commissioner points out that withdrawing the right to vote from someone protects neither the person nor society, but rather maintains exclusion and stigma. It also deprives society from having its full diversity represented at elections. For people with intellectual disabilities, it takes away their chance of shaping the policies and measures directly affecting their lives.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['black americans']
#
# --- Flag: CONFLICTING ---
#   Snippet queries used: ['Jul 17, 2018', '“No one should be deprived of their right to vote because of their disabilities. Persons with intellectual and psychosocial disabilities are no exception.”']
#   Entity queries used:  ['black americans']
#   Total queries:        4
#
# ================================================================================
# Case 4/20
# Claim ID: 6906  |  Label: Half True/False  |  Chunk Score: 0.900
# Claim:    "[A]t his current rate, President Obama will have added more debt to the United State of America by the end of his first term than each of the previous 43 presidents -- combined!"
# Question: Who will have added more debt to the United States of America by the end of his first term?"
# Evidence Source: chunk_only
#
# --- Original Snippet ---
# Jun 24, 2024 ... President Biden's executive actions have added $1.2 trillion to ten-year debt so far. ... Adding trillions more to the national debt will only ...
#
# --- Retrieved Chunk (score=0.900) ---
# Debt held by the public has grown by $6.0 trillion during President Biden’s term so far. - President Trump’s executive actions added less than $20 billion to ten-year debt on net. President Biden’s executive actions have added $1.2 trillion to ten-year debt so far.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['president obama', 'united states of america']
#
# --- Flag: POSSIBLY_FALSE ---
#   Snippet queries used: ['Jun 24, 2024', "President Biden's executive actions have added $1.2 trillion to ten-year debt so far.", 'Adding trillions more to the national debt will only']
#   Entity queries used:  ['president obama', 'united states of america']
#   Total queries:        6
#
# ================================================================================
# Case 5/20
# Claim ID: 10117  |  Label: True  |  Chunk Score: 0.756
# Claim:    "Firearms homicides are down about 40 percent" since Texas passed concealed-gun permit law.
# Question: Which state's concealed-gun permit law has reduced 40 percent or more?
# Evidence Source: chunk_only
#
# --- Original Snippet ---
# Jun 11, 2015 ... ... percent reduction in the state's firearm-related ... Ten states plus the District of Columbia have handgun purchaser licensing laws.
#
# --- Retrieved Chunk (score=0.756) ---
# While all 10 states in our “making progress” tier have made significant additions to their firearm laws in recent years—with a strong majority adding several points to its gun law score—a whopping 28 states at the other end of the scale have made the dangerous decision to repeal their concealed carry permit requirements. Our gun law rankings are a roadmap for how to build the ideal state system. They will walk you through the most important policies and help you compare these protections across the country.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['texas']
#
# --- Flag: POSSIBLY_FALSE ---
#   Snippet queries used: ['Jun 11, 2015', "percent reduction in the state's firearm-related", 'Ten states plus the District of Columbia have handgun purchaser licensing laws.']
#   Entity queries used:  ['texas']
#   Total queries:        5
#
# ================================================================================
# Case 6/20
# Claim ID: 13106  |  Label: False  |  Chunk Score: 0.697
# Claim:    The UPA govt purchased Indian-made military shoes from Israel for 10 times their actual price.
# Question: Which country purchased Indian-made military shoes for 10 times their actual price?
# Evidence Source: chunk_and_snippet
#
# --- Original Snippet ---
# Discover our exclusive direct-to-consumer handcrafted Goodyear-welted & hand-welted leather shoes—small batch, semi-bespoke, built for perfection.
#
# --- Retrieved Chunk (score=0.697) ---
# We have made it our mission to contribute to its preservation and promote standards of both Indian craftsmanship and the craftsmen themselves by paying them more than the Industry standards. Hand-welted shoes enjoy a long history but are losing their visibility with many premium brands and retailers misleading the consumers by branding non hand-grade shoes as Handcrafted shoes and charging a premium for a lower quality shoe. Hence, we at BLKBRD, thrive to give true shoe enthusiasts an honest and attainable alternative.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['israel', 'upa government']
#
# --- Flag: CONFLICTING ---
#   Snippet queries used: ['Discover our exclusive direct-to-consumer handcrafted Goodyear-welted & hand-welted leather shoes—small batch, semi-bespoke, built for perfection.']
#   Entity queries used:  ['israel', 'upa government']
#   Total queries:        4
#
# ================================================================================
# Case 7/20
# Claim ID: 8350  |  Label: True  |  Chunk Score: 0.670
# Claim:    At least two planes have crashed during special flights designed to reveal the sex of upcoming births with messages to onlookers below.
# Question: At least two planes have crashed during special flights?
# Evidence Source: chunk_and_snippet
#
# --- Original Snippet ---
# Feb 2, 2025 ... ... has happened in the last two weeks. More replies. 13 more replies ... The type of aircraft I own had an accident a week last year within our fleet ...
#
# --- Retrieved Chunk (score=0.670) ---
# The deadly collision follows a recent string of aviation related incidents. Last month a helicopter collided with an American Airlines passenger plane in Washington DC, killing all 64 passengers and three crew members. The same week, a small medical transport plane crashed into several buildings in the US city of Philadelphia, killing all six people on board and at least one other person on the ground.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['crashes']
#
# --- Flag: CONFLICTING ---
#   Snippet queries used: ['Feb 2, 2025', 'has happened in the last two weeks. More replies. 13 more replies', 'The type of aircraft I own had an accident a week last year within our fleet']
#   Entity queries used:  ['crashes']
#   Total queries:        5
#
# ================================================================================
# Case 8/20
# Claim ID: 3093  |  Label: Half True/False  |  Chunk Score: 0.602
# Claim:    The Guardian deactivated its 2021 "Person of the Year" poll after J.K. Rowling took the lead.
# Question: Who took the lead in the Guardian's 2021 poll?
# Evidence Source: chunk_and_snippet
#
# --- Original Snippet ---
# Jan 4, 2022 ... Our verdict. The article was not a poll but a request for readers to nominate their “Person of the Year” ...
#
# --- Retrieved Chunk (score=0.602) ---
# The Breitbart article contains a number of inaccuracies. Firstly, the Guardian did not run a “poll”. It asked readers to contribute their own “Person of the Year” suggestions after TIME magazine awarded the billionaire entrepreneur Elon Musk the title.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['guardian']
#
# --- Flag: CONFLICTING ---
#   Snippet queries used: ['Jan 4, 2022', 'Our verdict. The article was not a poll but a request for readers to nominate their “Person of the Year”']
#   Entity queries used:  ['guardian']
#   Total queries:        4
#
# ================================================================================
# Case 9/20
# Claim ID: 10440  |  Label: False  |  Chunk Score: 0.767
# Claim:    The voting bill known as H.R. 1 "would force states to adopt universal mail-in ballots.”
# Question: What bill would force states to adopt universal mail-in ballots?
# Evidence Source: chunk_only
#
# --- Original Snippet ---
# Mar 5, 2021 ... Since January, more than 250 bills that would restrict access to voting ... 1 would unfairly "force states to adopt universal mail-in ballots.
#
# --- Retrieved Chunk (score=0.767) ---
# Then-President Donald Trump seized on the practice -- both before and after his defeat -- to push unsupported claims that mail-in ballots are subject to greater risk of fraud, something experts have refuted. Since January, more than 250 bills that would restrict access to voting have been introduced in 43 statehouses, according to Brennan Center for Justice officials. The "biggest chunk" of these proposals would "limit who can vote by mail and how easy it is to vote by mail," said Eliza Sweren-Becker, counsel in the Brennan Center's Democracy Program.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['states', 'universal mail-in ballots']
#
# --- Flag: POSSIBLY_FALSE ---
#   Snippet queries used: ['Mar 5, 2021', 'Since January, more than 250 bills that would restrict access to voting', '1 would unfairly "force states to adopt universal mail-in ballots.']
#   Entity queries used:  ['states', 'universal mail-in ballots']
#   Total queries:        6
#
# ================================================================================
# Case 10/20
# Claim ID: 13965  |  Label: False  |  Chunk Score: 0.740
# Claim:    Says the new Dodd-Frank financial law requires a 20 percent down payment to buy a house.
# Question: Who says it requires a 20 percent down payment to buy a house?
# Evidence Source: chunk_only
#
# --- Original Snippet ---
# Jul 12, 2023 ... We had to get a bank statement loan and they required a 20% down payment. ... 20 percent down is abnormal for the average home buyers based on the ...
#
# --- Retrieved Chunk (score=0.740) ---
# was 19% of the purchase price — but for first-time buyers specifically, it was just 10%. If you’re thinking about buying a home, you may assume you need a 20% down payment. But while that number has been considered the standard for many years, most mortgages don’t require a full 20% down — and it’s definitely not typical for first-time homebuyers.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['new dodd-frank financial law require 20']
#
# --- Flag: POSSIBLY_FALSE ---
#   Snippet queries used: ['Jul 12, 2023', 'We had to get a bank statement loan and they required a 20% down payment.', '20 percent down is abnormal for the average home buyers based on the']
#   Entity queries used:  ['new dodd-frank financial law require 20']
#   Total queries:        5
#
# ================================================================================
# Case 11/20
# Claim ID: 11358  |  Label: True  |  Chunk Score: 0.704
# Claim:    "We have 17 intelligence agencies, civilian and military, who have all concluded that these espionage attacks, these cyberattacks, come from the highest levels of the Kremlin, and they are designed to influence our election."
# Question: Which of the 17 intelligence agencies have concluded that these espionage attacks, these cyberattacks, come from the highest levels?
# Evidence Source: chunk_only
#
# --- Original Snippet ---
# “We have 17 — 17 intelligence agencies, civilian and military, who have all concluded that these espionage attacks, these cyberattacks, come from the highest ...
#
# --- Retrieved Chunk (score=0.704) ---
# While the leaked material is still relevant — no one has disputed its veracity — the public castigation of Russia in this one instance does raise some questions: Do we really need 17 intelligence agencies investigating the same problem when there are so many provocations going unaddressed? - Are 17 US intelligence agencies really involved in determining the origin of hacking? More likely, one or two agencies have traced the hacking and others signed on. But if it is as Clinton claims and 17 agencies were working on the problem, then isn’t this an example of government waste? Do we really need 17 intelligence agencies investigating the same problem when there are so many provocations going unaddressed? - More importantly, in 2014 Chinese hackers penetrated the Office of Personnel Management and stole 22 million US personnel files including security clearance applications and fingerprints. (Full disclosure: I was informed my information and fingerprints were among those stolen).
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     partial_match_entities_missing
#   Matching:   ['kremlin']
#   Missing:    ['cyberattacks', '17 intelligence agencies']
#
# --- Flag: POSSIBLY_FALSE ---
#   Snippet queries used: ['“We have 17 — 17 intelligence agencies, civilian and military, who have all concluded that these espionage attacks, these cyberattacks, come from the highest']
#   Entity queries used:  ['17 intelligence agencies', 'kremlin', 'cyberattacks']
#   Total queries:        5
#
# ================================================================================
# Case 12/20
# Claim ID: 3105  |  Label: False  |  Chunk Score: 0.707
# Claim:    In August 2018, "liberals" started a GoFundMe campaign to raise murder suspect Cristhian Rivera's $5,000,000 bail.
# Question: Who started a GoFundMe campaign to raise the $5,000,000 bail for the murder suspect?
# Evidence Source: chunk_and_snippet
#
# --- Original Snippet ---
# Aug 24, 2018 ... Advertisment: Claim: In August 2018, "liberals" started a GoFundMe campaign to raise murder suspect Cristhian Rivera's $5,000,000 bail.
#
# --- Retrieved Chunk (score=0.707) ---
# Trump (@realDonaldTrump) August 22, 2018 The politicization of Tibbetts' death continued in the days following the arrest of Rivera, whom authorities in Iowa say led them to her remains and has confessed to the murder. On 23 August, the right-wing junk news Facebook page "Uncle Sam's Misguided Children" posted a widely-shared meme which claimed that "liberals" had started a GoFundMe campaign to collectively raise $5,000,000 for Rivera's bail. It contained what was presented as a screenshot from the GoFundMe website, along with the introductory message: "Liberals raising the bail money for a murder [sic] just #WalkAway." "Uncle Sam's Misguided Children" added: "Is this for real? Are Democrats raising money for this [piece of shit]?" #WalkAway is an online campaign which purports to represent individuals who have left the Democratic party, supposedly in dismay at left-wing policies and vehement criticism or disparagement of President Donald Trump.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     partial_match_entities_missing
#   Matching:   ['gofundme', 'cristhian rivera']
#   Missing:    ['murder suspect']
#
# --- Flag: CONFLICTING ---
#   Snippet queries used: ['Aug 24, 2018', 'Advertisment: Claim: In August 2018, "liberals" started a GoFundMe campaign to raise murder suspect Cristhian Rivera\'s $5,000,000 bail.']
#   Entity queries used:  ['cristhian rivera', 'murder suspect', 'gofundme']
#   Total queries:        6
#
# ================================================================================
# Case 13/20
# Claim ID: 6404  |  Label: True  |  Chunk Score: 0.677
# Claim:    In Florida, "the number of voters who now register as ‘other’ has grown by a million in the last 10 years. Compare that with the Democrats, who only grew by 300,000 and the Republicans who grew by just 200,000."
# Question: Which party grew by less than 300,000 voters?
# Evidence Source: chunk_and_snippet
#
# --- Original Snippet ---
# Mar 20, 2025 ... ... 300,000 then-registered voters lacked an appropriate identification card. ... less than 100% and greater than 94%. What Predicts Fewer ID ...
#
# --- Retrieved Chunk (score=0.677) ---
# What Predicts Fewer ID Holders? The population without a DMV ID card is evidently small, but it could be concentrated among particular groups of people. To measure this, I designed a linear regression model predicting the ratio of ID holders per 100 adults in each census tract. The dependent variable is adult ID holders as a percentage of the adult population and the independent variables are listed with their coefficients in the table.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['democrats']
#
# --- Flag: CONFLICTING ---
#   Snippet queries used: ['Mar 20, 2025', '300,000 then-registered voters lacked an appropriate identification card.', 'less than 100% and greater than 94%. What Predicts Fewer ID']
#   Entity queries used:  ['democrats']
#   Total queries:        5
#
# ================================================================================
# Case 14/20
# Claim ID: 3933  |  Label: False  |  Chunk Score: 0.799
# Claim:    Video shows undercover FBI agent being accidentally arrested during the 2020 US protests.
# Question: Which FBI agent was arrested by accident?
# Evidence Source: chunk_and_snippet
#
# --- Original Snippet ---
# Jul 14, 2025 ... Stephenson was charged with DUI, resisting arrest and leaving the scene of an accident. WVLT News reached out to the FBI office in Knoxville, ...
#
# --- Retrieved Chunk (score=0.799) ---
# The report said deputies later found keys to the truck in Stephenson’s pocket, and investigators found a damaged mailbox on Shipe Road that was “consistent with the front end damage” on Stephenson’s truck. Stephenson was charged with DUI, resisting arrest and leaving the scene of an accident. WVLT News reached out to the FBI office in Knoxville, but a spokesperson said the FBI doesn’t confirm employment as a standard practice.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['protests', 'undercover fbi agent']
#
# --- Flag: CONFLICTING ---
#   Snippet queries used: ['Jul 14, 2025', 'Stephenson was charged with DUI, resisting arrest and leaving the scene of an accident. WVLT News reached out to the FBI office in Knoxville,']
#   Entity queries used:  ['undercover fbi agent', 'protests']
#   Total queries:        5
#
# ================================================================================
# Case 15/20
# Claim ID: 2515  |  Label: Half True/False  |  Chunk Score: 0.781
# Claim:    "We've got 7.2 percent unemployment (in Ohio), but when you include the folks who have stopped looking for work, it's actually over 10 percent."
# Question: Which country has 7.2 percent unemployment?
# Evidence Source: chunk_and_snippet
#
# --- Original Snippet ---
# Jul 26, 2023 ... In May 2023, the unemployment rate in Wards 7 and 8 was 7.2 percent and 9.1 percent, respectively, Department of Employment Services (DOES) data ...
#
# --- Retrieved Chunk (score=0.781) ---
# Unemployment in DC is also geographically concentrated, following—and likely reinforcing—patterns of racial segregation. In May 2023, the unemployment rate in Wards 7 and 8 was 7.2 percent and 9.1 percent, respectively, Department of Employment Services (DOES) data show (Figure 1). By comparison, the unemployment rate in predominantly white Ward 3 was lowest at 3.6 percent.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['ohio']
#
# --- Flag: CONFLICTING ---
#   Snippet queries used: ['Jul 26, 2023', 'In May 2023, the unemployment rate in Wards 7 and 8 was 7.2 percent and 9.1 percent, respectively, Department of Employment Services (DOES) data']
#   Entity queries used:  ['ohio']
#   Total queries:        4
#
# ================================================================================
# Case 16/20
# Claim ID: 9084  |  Label: False  |  Chunk Score: 0.839
# Claim:    CCTV footage shows a minor Hindu boy being stabbed and killed by two boys from the Muslim community.
# Question: Which boy was stabbed and killed by two boys?
# Evidence Source: chunk_only
#
# --- Original Snippet ---
# Feb 21, 2025 ... When officers arrived at the scene, the Chicago Fire Department was treating the 11-year-old boy, who had multiple stab wounds to the chest.
#
# --- Retrieved Chunk (score=0.839) ---
# When officers arrived at the scene, the Chicago Fire Department was treating the 11-year-old boy, who had multiple stab wounds to the chest. He was transported to Comer Children's Hospital in critical condition. There was a heart-wrenching embrace outside of Comer Children's Hospital Friday night, after the family's matriarch made the gruesome discovery of her daughter, left clinging to life.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['minor hindu boy', 'incident']
#
# --- Flag: POSSIBLY_FALSE ---
#   Snippet queries used: ['Feb 21, 2025', 'When officers arrived at the scene, the Chicago Fire Department was treating the 11-year-old boy, who had multiple stab wounds to the chest.']
#   Entity queries used:  ['minor hindu boy', 'incident']
#   Total queries:        5
#
# ================================================================================
# Case 17/20
# Claim ID: 3070  |  Label: False  |  Chunk Score: 0.648
# Claim:    The Capitol Police released a statement expressing "profound disappointment" in Republican leadership's lack of support for the Jan. 6 commission.
# Question: Who expressed "profound disappointment" in Republican leadership's lack of support for the Jan. 6 commission?
# Evidence Source: chunk_and_snippet
#
# --- Original Snippet ---
# May 19, 2021 ... ... expressed "profound disappointment" with McCarthy and McConnell over their opposition. "On Jan. 6th, where some officers served their last ...
#
# --- Retrieved Chunk (score=0.648) ---
# "Others who, I think, believe it will be counterproductive because of the work that's already been done and that it could be weaponized politically and drug into next year." Outside support for commission In a letter to members of Congress, members of the U.S. Capitol Police expressed "profound disappointment" with McCarthy and McConnell over their opposition. 6th, where some officers served their last day in a US Capitol Police uniform, and not by choice, we would hope that the Members whom we took an oath to protect, would at the very minimum, support an investigation to get to the bottom of EVERYONE responsible and hold them 100 percent accountable no matter the title or position they hold or held," their letter reads.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['capitol police', 'jan. 6 commission', 'republican leadership']
#
# --- Flag: CONFLICTING ---
#   Snippet queries used: ['May 19, 2021', 'expressed "profound disappointment" with McCarthy and McConnell over their opposition. "On Jan. 6th, where some officers served their last']
#   Entity queries used:  ['capitol police', 'jan. 6 commission', 'republican leadership']
#   Total queries:        6
#
# ================================================================================
# Case 18/20
# Claim ID: 11075  |  Label: False  |  Chunk Score: 0.811
# Claim:    A California halfway house resident was promised $300 if he voted for Hillary Clinton.
# Question: Which candidate promised $300 to a California halfway house resident?
# Evidence Source: chunk_only
#
# --- Original Snippet ---
# Your principal residence is the home where you ordinarily live most of the time. ... These contributions aren't income to a candidate unless they're diverted to ...
#
# --- Retrieved Chunk (score=0.811) ---
# Your principal residence is the home where you ordinarily live most of the time. You can have only one principal residence at any one time. Amount eligible for exclusion.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['california halfway house']
#
# --- Flag: POSSIBLY_FALSE ---
#   Snippet queries used: ['Your principal residence is the home where you ordinarily live most of the time.', "These contributions aren't income to a candidate unless they're diverted to"]
#   Entity queries used:  ['california halfway house']
#   Total queries:        4
#
# ================================================================================
# Case 19/20
# Claim ID: 1437  |  Label: False  |  Chunk Score: 0.690
# Claim:    Anyone struggling financially, with less than £4 on a prepayment energy meter, can call their energy supplier and ask for a £49 fuel voucher twice a year.
# Question: Who can get a 49 fuel voucher twice a year?
# Evidence Source: chunk_and_snippet
#
# --- Original Snippet ---
# Feb 9, 2022 ... Our verdict. This is not an established scheme across the UK. Financial support with energy bills is available but the claim ...
#
# --- Retrieved Chunk (score=0.690) ---
# Support with energy bills With energy prices due to increase sharply, it has been reported that millions more households in the UK will face “fuel stress”. There are a number of government-run schemes available for people who are struggling to pay their energy bills, for example the Warm Home Discount Scheme through which eligible people can get a one-off £140 discount on (or equivalent voucher toward) their energy bill covering the period from October to March. This scheme does not run in Northern Ireland, though there is other support available such as the Affordable Warmth Scheme.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['prepayment energy meter users']
#
# --- Flag: CONFLICTING ---
#   Snippet queries used: ['Feb 9, 2022', 'Our verdict. This is not an established scheme across the UK. Financial support with energy bills is available but the claim']
#   Entity queries used:  ['prepayment energy meter users']
#   Total queries:        4
#
# ================================================================================
# Case 20/20
# Claim ID: 12904  |  Label: False  |  Chunk Score: 0.604
# Claim:    In February 2021, 81 percent of Indians wore masks but COVID cases went up 2,966 percent.
# Question: Which disease was found in more than half of the Indian population?
# Evidence Source: chunk_and_snippet
#
# --- Original Snippet ---
# Dec 18, 2024 ... Nearly half (49%) of uninsured adults say they have difficulty affording health care costs, more than double the share of those with private ...
#
# --- Retrieved Chunk (score=0.604) ---
# This anticipated coverage loss will have implications for access to care and financial stability among those losing coverage and could lead to a worsening of disparities in health outcomes. This issue brief describes trends in health coverage through 2024, examines the characteristics of the uninsured population ages 0-64, and summarizes the access and financial implications of not having coverage. Using data from the American Community Survey (ACS), this analysis examines changes in health coverage from 2023 to 2024.
#
# --- Entity Comparison ---
#   Verdict:    CONFLICTING
#   Reason:     no_matching_entities
#   Matching:   []
#   Missing:    ['indians', 'masks', 'covid cases']
#
# --- Flag: CONFLICTING ---
#   Snippet queries used: ['Dec 18, 2024', 'Nearly half (49%) of uninsured adults say they have difficulty affording health care costs, more than double the share of those with private']
#   Entity queries used:  ['indians', 'masks', 'covid cases']
#   Total queries:        6

# %% [markdown]
# ## 12. Export Enriched JSON

# %%
from collections import defaultdict

export = defaultdict(lambda: {
    "claim": "", "label": "", "category": "", "taxonomy": "", "questions": []
})

for rec in output_records:
    sid = rec["claim_id"]
    export[sid]["claim"]    = rec["claim"]
    export[sid]["label"]    = rec["label"]
    export[sid]["category"] = rec["category"]
    export[sid]["taxonomy"] = rec["taxonomy"]
    export[sid]["questions"].append({
        "q_idx":               rec["q_idx"],
        "our_question":        rec["our_question"],
        "matched_qt_q":        rec["matched_qt_q"],
        "match_score":         rec["match_score"],
        "used_url":            rec["used_url"],
        "fetch_source":        rec["fetch_source"],
        # Evidence
        "original_snippet":    rec["original_snippet"],
        "snippet_queries":     rec["snippet_queries"],
        "entity_queries":      rec["entity_queries"],
        "num_queries_used":    rec["num_queries_used"],
        "best_chunk":          rec["best_chunk"],
        "best_score":          rec["best_score"],
        "primary_evidence":    rec["primary_evidence"],
        "evidence_source":     rec["evidence_source"],
        "top_chunks_above_mid": rec["top_chunks_above_mid"],
        # Entities
        "target_entity":       rec["target_entity"],
        "entity_type":         rec["entity_type"],
        "our_entities":        rec["our_entities"],
        "qt_entities":         rec["qt_entities"],
        "missing_entities":    rec["missing_entities"],
        "chunk_entities":      rec["chunk_entities"],
        "entity_comparison":   rec["entity_comparison"],
        # Flags
        "our_present":         rec["our_present"],
        "qt_present":          rec["qt_present"],
        "missing_recovered":   rec["missing_recovered"],
        "flag":                rec["flag"],
    })

with open(FINAL_OUTPUT_PATH, "w") as f:
    json.dump(dict(export), f, indent=2)
print(f"Saved {len(export)} claim records to '{FINAL_OUTPUT_PATH}'")

from google.colab import files
files.download(FINAL_OUTPUT_PATH)
files.download(CHECKPOINT_PATH)
# Out:
# Saved 15415 claim records to '/content/claim_verification_results_v2.json'

# %% [markdown]
# ## 13. Summary Statistics

# %%
import pandas as pd

df = pd.DataFrame(output_records)

print("=== Flag Distribution ===")
print(df["flag"].value_counts().to_string())

print("\n=== Evidence Source Distribution ===")
print(df["evidence_source"].value_counts().to_string())

print("\n=== Fetch Source Distribution ===")
print(df["fetch_source"].value_counts().to_string())

print("\n=== Chunk Score Distribution ===")
bins   = [0, 0.3, 0.5, 0.7, 1.0]
labels_b = ["<0.3", "0.3-0.5", "0.5-0.7", ">0.7"]
df["score_bin"] = pd.cut(df["best_score"], bins=bins, labels=labels_b)
print(df["score_bin"].value_counts().sort_index().to_string())

print("\n=== Entity Comparison Verdict Distribution ===")
verdicts = df["entity_comparison"].apply(
    lambda x: x.get("verdict", "N/A") if isinstance(x, dict) else "N/A"
)
print(verdicts.value_counts().to_string())

print("\n=== Missing Entity Recovery Rate ===")
has_missing = df[df["missing_entities"].map(len) > 0]
recovered   = has_missing["missing_recovered"].sum()
print(f"  {recovered}/{len(has_missing)} questions recovered at least one missing entity ({100*recovered/max(len(has_missing),1):.1f}%)")

print("\n=== Flag by Taxonomy ===")
print(df.groupby("taxonomy")["flag"].value_counts().unstack(fill_value=0).to_string())

print("\n=== Avg Queries Used per Fetched Article ===")
fetched = df[df["num_queries_used"] > 0]
print(f"  Mean: {fetched['num_queries_used'].mean():.1f}  Max: {fetched['num_queries_used'].max()}")

# %% [markdown]
# ## Generate Signals

# %%
import json
from collections import defaultdict

# ── Load checkpoint ───────────────────────────────────────────
with open("/content/drive/MyDrive/claim_verification_analysis_updated_v2/checkpoint_records_merged.json") as f:
    records = json.load(f)

# ── Build lookup: claim_id -> list of question records ────────
claim_groups = defaultdict(list)
for r in records:
    claim_groups[r["claim_id"]].append(r)

# ── Compute entity signal per claim ───────────────────────────
def compute_entity_signal(recs):
    """
    Collect all target entities across all questions for this claim.
    Collect all chunk_entities extracted from retrieved chunks.
    Do one set comparison across the whole claim.
    """
    # All target entities from QT questions (what we're looking for)
    target_set = set()
    for r in recs:
        for e in r.get("qt_entities", []):
            text = e[0] if isinstance(e, list) else e.get("text", "")
            if text:
                target_set.add(text.lower().strip())

    # All entities actually found in retrieved chunks
    chunk_set = set()
    for r in recs:
        for e in r.get("chunk_entities", []):
            text = e.get("text", "") if isinstance(e, dict) else str(e)
            if text:
                chunk_set.add(text.lower().strip())

    if not target_set:
        return "some_present"   # no target to compare against

    intersection = target_set & chunk_set
    match_ratio  = len(intersection) / len(target_set)

    if match_ratio == 1.0:   return "all_present"
    elif match_ratio == 0.0: return "none_present"
    else:                    return "some_present"
entity_signal_map = {
    cid: compute_entity_signal(recs)
    for cid, recs in claim_groups.items()
}

# ── Build chunk lookup: claim_id -> sorted list of question dicts ─
chunk_lookup = {}
for cid, recs in claim_groups.items():
    sorted_recs = sorted(recs, key=lambda r: r["q_idx"])
    chunk_lookup[cid] = [
        {
            "question": r["our_question"],
            "top_k_doc": (
                [c["text"] for c in r["top_chunks_above_mid"]]
                if r.get("top_chunks_above_mid")
                else [r["original_snippet"]]   # fallback
            )
        }
        for r in sorted_recs
    ]

# ── Load and enrich converted.json ───────────────────────────
INPUT_PATH  = "/content/drive/MyDrive/claim_verification_analysis_updated_v2/converted.json"
OUTPUT_PATH = "/content/drive/MyDrive/claim_verification_analysis_updated_v2/converted_with_signal.json"

with open(INPUT_PATH) as f:
    data = json.load(f)

# ── Alignment check ───────────────────────────────────────────
checkpoint_ids = set(entity_signal_map.keys())
data_ids       = set(str(i) for i in range(len(data)))
print(f"Checkpoint claims : {len(checkpoint_ids)}")
print(f"converted.json    : {len(data)}")

missed = 0
for i, item in enumerate(data):
    cid = str(i)   # claim_id in checkpoint is row index as string
    if cid in chunk_lookup:
        item["reranked_our_evidences"] = chunk_lookup[cid]
        item["entity_signal"]          = entity_signal_map[cid]
    else:
        # keep original evidences, set signal to unknown
        item["entity_signal"] = "some_present"
        missed += 1

print(f"Claims updated    : {len(data) - missed}")
print(f"Fallback (missed) : {missed}")

with open(OUTPUT_PATH, "w") as f:
    json.dump(data, f, indent=2)
print(f"\nSaved → {OUTPUT_PATH}")

# ── Sanity check one record ───────────────────────────────────
print("\n=== Sample record ===")
print(json.dumps(data[0], indent=2)[:800])
# Out:
# Checkpoint claims : 15478
# converted.json    : 15478
# Claims updated    : 15478
# Fallback (missed) : 0
#
# Saved → /content/drive/MyDrive/claim_verification_analysis_updated_v2/converted_with_signal.json
#
# === Sample record ===
# {
#   "claim": "\"The non-partisan Congressional Budget Office concluded ObamaCare will cost the U.S. more than 800,000 jobs.\"",
#   "label": "Conflicting",
#   "category": "test",
#   "taxonomy": "Statistical",
#   "reranked_our_evidences": [
#     {
#       "question": "Who concluded ObamaCare will cost the U.S. 800,000 jobs?",
#       "top_k_doc": [
#         "The Congressional Budget Office says Obamacare will result in 800,000 fewer American jobs. Many business owners express concerns and confusion about what how the law will impact their business and their bottom line. \u201cI\u2019ve met with thousands of South Carolina business owners and job creators in the two years since this was passed into law,\u201d said Graham.",
#         "Thus far, the Obama Administration has issued at least 1,722 waivers c

# %% [markdown]
# ## for temporal NEw evidences

# %%
import pandas as pd
df = pd.read_json("Processed_complete_dataset_with_new_temporal_evidences.json")
df.head()
# Out:
#                                                claim  \
# 0  "The non-partisan Congressional Budget Office ...
# 1  "More than 50 percent of immigrants from (El S...
# 2  "[In 2014-2015] coverage for the rotavirus vac...
# 3       Labour took £1.5 million from Just Stop Oil.
# 4  McDonald's has announced that everyone who sha...
#
#                                   quantemp_evidences        label Category  \
# 0  [{'questions': 'did the congressional budget o...  Conflicting     test
# 1  [{'questions': 'do more than 50 percent of imm...         True     test
# 2  [{'questions': 'did the coverage for the rotav...        False     test
# 3  [{'questions': 'did labour receive a donation ...        False     test
# 4  [{'questions': 'is it true that mcdonald's has...        False     test
#
#                                        our_evidences     taxonomy  \
# 0  [{'question': 'Who concluded ObamaCare will co...  Statistical
# 1  [{'question': 'Which country has over 50 perce...  Statistical
# 2  [{'question': 'Which vaccine had 91.5% coverag...  Statistical
# 3  [{'question': 'Who took more than £1.5 million...  Statistical
# 4  [{'question': 'Who shares this link will recei...  Statistical
#
#                               reranked_our_evidences
# 0  [{'questions': 'Who concluded ObamaCare will c...
# 1  [{'questions': 'Which country has over 50 perc...
# 2  [{'questions': 'Which vaccine had 91.5% covera...
# 3  [{'questions': 'Who took more than £1.5 millio...
# 4  [{'questions': 'Who shares this link will rece...

# %%
df.shape
# Out:
# (15415, 7)

# %%
df2 = df[df.taxonomy == 'Temporal']
df2
# Out:
#                                                    claim  \
# 11285   Kyiv cut off gas in the territory of Luhansk ...
# 11286   Photo showing a car carrying russian diplomat...
# 11287   Photograph showing jets at the Forum in Davos...
# 11288   There are photos of documents of captured sol...
# 11289   There is a photo of russian Ka-52 helicopter ...
# ...                                                  ...
# 15410  “Tim Ryan when he ran for president two years ...
# 15411  “Tim Tebow says he is wearing #85 to honor his...
# 15412  “Wladimir Klitschko has auctioned off his 1996...
# 15413  “World Health Organization wants to BAN all wo...
# 15414  “‘The Simpsons' predicted Tom Hanks getting co...
#
#                                       quantemp_evidences            label  \
# 11285  [{'questions': 'did kyiv cut off gas in the te...            False
# 11286  [{'questions': 'is there a photo showing a car...            False
# 11287  [{'questions': 'is the forum in davos hosting ...            False
# 11288  [{'questions': 'are there photos of documents ...            False
# 11289  [{'questions': 'is there a photo of a russian ...            False
# ...                                                  ...              ...
# 15410  [{'questions': 'did tim ryan run for president...  Half True/False
# 15411  [{'questions': 'is tim tebow wearing #85 to ho...            False
# 15412  [{'questions': 'did wladimir klitschko auction...      Conflicting
# 15413  [{'questions': 'is the world health organizati...            False
# 15414  [{'questions': 'did "the simpsons" predict tom...            False
#
#          Category                                      our_evidences  \
# 11285       train  [{'question': 'Which country cut off gas in th...
# 11286       train  [{'question': 'Which car carrying russian dipl...
# 11287       train  [{'question': 'Which photograph shows jets at ...
# 11288       train  [{'question': 'Which photos of captured soldie...
# 11289       train  [{'question': 'Which russian Ka-52 helicopter ...
# ...           ...                                                ...
# 15410       train  [{'question': 'Which politician supported bann...
# 15411        test  [{'question': 'Who says he is wearing #85 to h...
# 15412        test  [{'question': 'Who has auctioned off his Atlan...
# 15413       train  [{'question': 'Which organization wants to BAN...
# 15414  validation  [{'question': 'Which episode predicted Tom Han...
#
#        taxonomy                             reranked_our_evidences
# 11285  Temporal  [{'question': 'Which country cut off gas in th...
# 11286  Temporal  [{'question': 'Which car carrying russian dipl...
# 11287  Temporal  [{'question': 'Which photograph shows jets at ...
# 11288  Temporal  [{'question': 'Which photos of captured soldie...
# 11289  Temporal  [{'question': 'Which russian Ka-52 helicopter ...
# ...         ...                                                ...
# 15410  Temporal  [{'question': 'Which politician supported bann...
# 15411  Temporal  [{'question': 'Who says he is wearing #85 to h...
# 15412  Temporal  [{'question': 'Who has auctioned off his Atlan...
# 15413  Temporal  [{'question': 'Which organization wants to BAN...
# 15414  Temporal  [{'question': 'Which episode predicted Tom Han...
#
# [4130 rows x 7 columns]

# %%
df2.to_json("temporal_dataset_with_new_evidences.json", indent=2, orient='records')

# %%
import pandas as pd
df4 = pd.read_json("/content/claim_verification_results_v2.json")
df4
# Out:
#                                                        0      \
# claim      "The non-partisan Congressional Budget Office ...
# label                                            Conflicting
# category                                                test
# taxonomy                                         Statistical
# questions  [{'q_idx': 0, 'our_question': 'Who concluded O...
#
#                                                        1      \
# claim      "More than 50 percent of immigrants from (El S...
# label                                                   True
# category                                                test
# taxonomy                                         Statistical
# questions  [{'q_idx': 0, 'our_question': 'Which country h...
#
#                                                        2      \
# claim       Photograph showing jets at the Forum in Davos...
# label                                                  False
# category                                               train
# taxonomy                                            Temporal
# questions  [{'q_idx': 0, 'our_question': 'Which photograp...
#
#                                                        3      \
# claim      "[In 2014-2015] coverage for the rotavirus vac...
# label                                                  False
# category                                                test
# taxonomy                                         Statistical
# questions  [{'q_idx': 0, 'our_question': 'Which vaccine h...
#
#                                                        4      \
# claim       There is a photo of russian Ka-52 helicopter ...
# label                                                  False
# category                                               train
# taxonomy                                            Temporal
# questions  [{'q_idx': 0, 'our_question': 'Which russian K...
#
#                                                        5      \
# claim           Labour took £1.5 million from Just Stop Oil.
# label                                                  False
# category                                                test
# taxonomy                                         Statistical
# questions  [{'q_idx': 0, 'our_question': 'Who took more t...
#
#                                                        6      \
# claim      McDonald's has announced that everyone who sha...
# label                                                  False
# category                                                test
# taxonomy                                         Statistical
# questions  [{'q_idx': 0, 'our_question': 'Who shares this...
#
#                                                        7      \
# claim       meat and dairy products will be banned by 203...
# label                                                  False
# category                                                test
# taxonomy                                            Temporal
# questions  [{'q_idx': 0, 'our_question': 'Which products ...
#
#                                                        8      \
# claim       russia destroyed the S-300 air defense system...
# label                                                  False
# category                                               train
# taxonomy                                            Temporal
# questions  [{'q_idx': 0, 'our_question': 'Which country d...
#
#                                                        9      ...  \
# claim       russian occupiers try to push out stuck equip...  ...
# label                                                  False  ...
# category                                               train  ...
# taxonomy                                            Temporal  ...
# questions  [{'q_idx': 0, 'our_question': 'Which country’s...  ...
#
#                                                        15465  \
# claim      A U.S. tourist in Saudi Arabia was arrested fo...
# label                                                  False
# category                                          validation
# taxonomy                                         Statistical
# questions  [{'q_idx': 0, 'our_question': 'Which tourist r...
#
#                                                        15468  \
# claim      "Last month, more Americans stopped looking fo...
# label                                        Half True/False
# category                                          validation
# taxonomy                                          Comparison
# questions  [{'q_idx': 0, 'our_question': 'Which month had...
#
#                                                        15469  \
# claim      "In states where the federal government helps ...
# label                                        Half True/False
# category                                          validation
# taxonomy                                         Statistical
# questions  [{'q_idx': 0, 'our_question': 'Which state has...
#
#                                                        15470  \
# claim      Teeth whitening can be done using carrot, turm...
# label                                                  False
# category                                          validation
# taxonomy                                            Interval
# questions  [{'q_idx': 0, 'our_question': 'Which product c...
#
#                                                        15471  \
# claim      The 2020 election could not have been fair bec...
# label                                                  False
# category                                          validation
# taxonomy                                         Statistical
# questions  [{'q_idx': 0, 'our_question': 'Which county ag...
#
#                                                        15472  \
# claim      Hamburger Piraten-Prozess – Leben die Somalier...
# label                                        Half True/False
# category                                          validation
# taxonomy                                            Interval
# questions  [{'q_idx': 0, 'our_question': 'Which country h...
#
#                                                        15473  \
# claim      Mark Zuckerberg is giving $1,000 away to Faceb...
# label                                                  False
# category                                          validation
# taxonomy                                         Statistical
# questions  [{'q_idx': 0, 'our_question': 'Mark Zuckerberg...
#
#                                                        15475  \
# claim      "CNN to permanently close its doors as ratings...
# label                                                  False
# category                                          validation
# taxonomy                                         Statistical
# questions  [{'q_idx': 0, 'our_question': '"CNN to permane...
#
#                                                        15476  \
# claim      A recent study found "that cities where Uber o...
# label                                        Half True/False
# category                                          validation
# taxonomy                                          Comparison
# questions  [{'q_idx': 0, 'our_question': 'Which city has ...
#
#                                                        15477
# claim      The Biden administration "published a study co...
# label                                                   True
# category                                          validation
# taxonomy                                         Statistical
# questions  [{'q_idx': 0, 'our_question': 'Which of the 5 ...
#
# [5 rows x 12380 columns]

# %%
df4.shape
# Out:
# (5, 12380)
