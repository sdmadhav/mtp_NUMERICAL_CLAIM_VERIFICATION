# %% [markdown]
# # FinQA Roberta Large On OUR DATASET

# %%
# !gdown --id 1LR-w4kZ-r8KNV3IcXvvxMREWV2vQXx8Y
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1LR-w4kZ-r8KNV3IcXvvxMREWV2vQXx8Y
# From (redirected): https://drive.google.com/uc?id=1LR-w4kZ-r8KNV3IcXvvxMREWV2vQXx8Y&confirm=t&uuid=7011ac79-ad05-4f05-acea-99dc52bbef48
# To: /content/finqa_roberta_claimdecomp_early_stop_2.zip
# 100% 1.31G/1.31G [00:24<00:00, 53.8MB/s]

# %%
# !unzip /content/finqa_roberta_claimdecomp_early_stop_2.zip
# Out:
# Archive:  /content/finqa_roberta_claimdecomp_early_stop_2.zip
#    creating: finqa_roberta_claimdecomp_early_stop_2/
#   inflating: __MACOSX/._finqa_roberta_claimdecomp_early_stop_2
#   inflating: finqa_roberta_claimdecomp_early_stop_2/tokenizer_config.json
#   inflating: __MACOSX/finqa_roberta_claimdecomp_early_stop_2/._tokenizer_config.json
#   inflating: finqa_roberta_claimdecomp_early_stop_2/special_tokens_map.json
#   inflating: __MACOSX/finqa_roberta_claimdecomp_early_stop_2/._special_tokens_map.json
#   inflating: finqa_roberta_claimdecomp_early_stop_2/model_weights.zip
#   inflating: __MACOSX/finqa_roberta_claimdecomp_early_stop_2/._model_weights.zip
#   inflating: finqa_roberta_claimdecomp_early_stop_2/merges.txt
#   inflating: __MACOSX/finqa_roberta_claimdecomp_early_stop_2/._merges.txt
#   inflating: finqa_roberta_claimdecomp_early_stop_2/vocab.json
#   inflating: __MACOSX/finqa_roberta_claimdecomp_early_stop_2/._vocab.json

# %%
# !git clone https://github.com/sdmadhav/train_nli_model.git
# Out:
# Cloning into 'train_nli_model'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 35 (delta 13), reused 12 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 13.83 MiB | 15.03 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
# !mv /content/train_nli_model/our_train.json /content/our_train.json
# !mv /content/train_nli_model/our_val.json /content/our_val.json
# !mv /content/train_nli_model/our_test.json /content/our_test.json
# !mv /content/train_nli_model/train_nli_finqa_roberta_large.py /content/train_nli_finqa_roberta_large.py

# %%
# !python train_nli_finqa_roberta_large.py
# Out:
# Using device: cuda
#
# Loading data...
# Train: 9921 | Val: 3077 | Test: 2492
# Train labels: Counter({'False': 5765, 'Conflicting': 2335, 'True': 1821})
# Label mapping: {np.str_('Conflicting'): 0, np.str_('False'): 1, np.str_('True'): 2}
#
# Loading tokenizer: roberta-large-mnli
# ...
#
# Building features (num_evidences=2, max_length=256)...
# Tokenizing train...
# Tokenizing val...
# Tokenizing test...
#
# Building model: roberta-large-mnli
# Loading weights: 100% 391/391 [00:00<00:00, 860.12it/s, Materializing param=pooler.dense.weight]
# RobertaModel LOAD REPORT from: roberta-large-mnli
# Key                        | Status     |  |
# ---------------------------+------------+--+-
# classifier.dense.weight    | UNEXPECTED |  |
# classifier.out_proj.bias   | UNEXPECTED |  |
# classifier.out_proj.weight | UNEXPECTED |  |
# classifier.dense.bias      | UNEXPECTED |  |
#
# Notes:
# ...
